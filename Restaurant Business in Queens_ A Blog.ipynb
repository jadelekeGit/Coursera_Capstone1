# %% [markdown]
# # French' Restaurant Business in Queens, NYC: A Blog

# %% [markdown]
# #### JULIEN ADELEKE

# %%
{
    "tags":[
        "remove-cell",
    ]
}

import numpy as np
import pandas as pd
pd.set_option('display.max_column', None)
pd.set_option('display.max_row', None)

import json
import xml

# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")

# !pip install geocoder
from geopy.geocoders import Nominatim
import requests
from pandas.io.json import json_normalize
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import matplotlib.colors as colors
from sklearn.cluster import KMeans

# !pip install folium
import folium
from bs4 import BeautifulSoup

print('Librairies imported.')
# Out:
# Collecting geocoder
#   Downloading geocoder-1.38.1-py2.py3-none-any.whl (98 kB)
#      |████████████████████████████████| 98 kB 8.5 MB/s  eta 0:00:01
# Requirement already satisfied: click in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from geocoder) (7.1.2)
# Requirement already satisfied: future in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from geocoder) (0.18.2)
# Requirement already satisfied: six in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from geocoder) (1.15.0)
# Requirement already satisfied: requests in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from geocoder) (2.24.0)
# Collecting ratelim
#   Downloading ratelim-0.1.6-py2.py3-none-any.whl (4.0 kB)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from requests->geocoder) (2020.12.5)
# Requirement already satisfied: chardet<4,>=3.0.2 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from requests->geocoder) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from requests->geocoder) (1.25.9)
# Requirement already satisfied: idna<3,>=2.5 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from requests->geocoder) (2.9)
# Requirement already satisfied: decorator in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from ratelim->geocoder) (4.4.2)
# Installing collected packages: ratelim, geocoder
# Successfully installed geocoder-1.38.1 ratelim-0.1.6
# Collecting folium
#   Downloading folium-0.12.1-py2.py3-none-any.whl (94 kB)
#      |████████████████████████████████| 94 kB 5.5 MB/s  eta 0:00:01
# Requirement already satisfied: requests in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from folium) (2.24.0)
# Collecting branca>=0.3.0
#   Downloading branca-0.4.2-py3-none-any.whl (24 kB)
# Requirement already satisfied: jinja2>=2.9 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from folium) (2.11.2)
# Requirement already satisfied: numpy in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from folium) (1.18.5)
# Requirement already satisfied: chardet<4,>=3.0.2 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from requests->folium) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from requests->folium) (2.9)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from requests->folium) (1.25.9)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from requests->folium) (2020.12.5)
# Requirement already satisfied: MarkupSafe>=0.23 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from jinja2>=2.9->folium) (1.1.1)
# Installing collected packages: branca, folium
# Successfully installed branca-0.4.2 folium-0.12.1
# Librairies imported.

# %%
{
    "tags":[
        "remove-cell",
    ]
}

#Loading data
# !wget -q -O 'newyork_data.json' https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0701EN-SkillsNetwork/labs/newyork_data.json
print('Data downloaded!')
# Out:
# Data downloaded!

# %%
{
    "tags":[
        "hide-input",
    ]
}

with open('newyork_data.json') as f:
    newyork_data = json.load(f)

# %%
{
    "tags":[
        "remove-cell",
    ]
}

neighborhoods_data = newyork_data['features']
neighborhoods_data[0]
# Out:
# {'type': 'Feature',
#  'id': 'nyu_2451_34572.1',
#  'geometry': {'type': 'Point',
#   'coordinates': [-73.84720052054902, 40.89470517661]},
#  'geometry_name': 'geom',
#  'properties': {'name': 'Wakefield',
#   'stacked': 1,
#   'annoline1': 'Wakefield',
#   'annoline2': None,
#   'annoline3': None,
#   'annoangle': 0.0,
#   'borough': 'Bronx',
#   'bbox': [-73.84720052054902,
#    40.89470517661,
#    -73.84720052054902,
#    40.89470517661]}}

# %%
{
    "tags":[
        "hide-input",
    ]
}

def get_newyork_data():
    url='https://cocl.us/new_york_dataset'
    resp=requests.get(url).json()
    # all data is present in features label
    features=resp['features']
    # define the dataframe columns
    column_names = ['Borough', 'Neighborhood', 'Latitude', 'Longitude'] 
    # instantiate the dataframe
    newyork_data = pd.DataFrame(columns=column_names)
    for data in features:
        borough = data['properties']['borough'] 
        neighborhood_name = data['properties']['name']
        neighborhood_latlon = data['geometry']['coordinates']
        neighborhood_lat = neighborhood_latlon[1]
        neighborhood_lon = neighborhood_latlon[0]
        newyork_data = newyork_data.append({'Borough': borough,
                                          'Neighborhood': neighborhood_name,
                                          'Latitude': neighborhood_lat,
                                          'Longitude': neighborhood_lon}, ignore_index=True)
    return newyork_data



def geo_location(address):
    # get geo location of address
    geolocator = Nominatim(user_agent="foursquare_agent")
    location = geolocator.geocode(address)
    latitude = location.latitude
    longitude = location.longitude
    return latitude,longitude



def get_venues(lat,lng):
    #set variables
    radius=400
    LIMIT=100
    #url to fetch data from foursquare api
    url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
    # get all the data
    results = requests.get(url).json()
    venue_data=results["response"]['groups'][0]['items']
    venue_details=[]
    for row in venue_data:
        try:
            venue_id=row['venue']['id']
            venue_name=row['venue']['name']
            venue_category=row['venue']['categories'][0]['name']
            venue_details.append([venue_id,venue_name,venue_category])
        except KeyError:
            pass
    column_names=['ID','Name','Category']
    df = pd.DataFrame(venue_details,columns=column_names)
    return df


def get_venue_details(venue_id):
    #url to fetch data from foursquare api
    url = 'https://api.foursquare.com/v2/venues/{}?&client_id={}&client_secret={}&v={}'.format(
            venue_id,
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION)
    # get all the data
    results = requests.get(url).json()
    print(results)
    venue_data=results['response']['venue']
    venue_details=[]
    try:
        venue_id=venue_data['id']
        venue_name=venue_data['name']
        venue_likes=venue_data['likes']['count']
        venue_rating=venue_data['rating']
        venue_tips=venue_data['tips']['count']
        venue_details.append([venue_id,venue_name,venue_likes,venue_rating,venue_tips])
    except KeyError:
        pass
    column_names=['ID','Name','Likes','Rating','Tips']
    df = pd.DataFrame(venue_details,columns=column_names)
    return df

# %% [markdown]
# ### New York City is the most populous city in the United states of America. It covers more than 302 square miles with a population of more than 8 millions people. With more than 20 millions people in its metropolitan statistical area NYC is certainly the largest metropolitan area in the world and is one of the world's most populous megacities. It's also one of the best tourist destination in the world and a great place for business. Described as the cultural, financial, and media capital of the world, significantly influencing commerce, entertainment, research, technology, education, politics, tourism, art, fashion, and sports. But NYC can be also thought as the Capital of gastronomy.

# %% [markdown]
# ### In Fact, as many as 800 languages are spoken in NYC, making it the most linguistically diverse city in the world. New York is home to more than 3.2 million residents born outside the United States, the largest foreign-born population of any city in the world. Each linguististic group comes with its culinary specialies. Thus, beside amercan specialities we have exotic cusines like those of Mexicans, Italians, Chineses, Indians and Frenchs to only name these. Flavors and smells mingle at the corner of the streets of NYC. However, the geographical distribution of restaurants in New York is uneven. In this blog I'm going to show that French restaurants are largely underrepresented in NYC and that there are almost absent in the largest borough of the City: Queens. NYC is composed of five Boroughs - Queens, Brooklyn, Staten Island, Bronx and Manhattan - in respect with their geographical size.

# %%
{
    "tags":[
        "hide-input",
    ]
}

newyork_data = get_newyork_data()
newyork_data.head()
# Out:
#   Borough Neighborhood   Latitude  Longitude
# 0   Bronx    Wakefield  40.894705 -73.847201
# 1   Bronx   Co-op City  40.874294 -73.829939
# 2   Bronx  Eastchester  40.887556 -73.827806
# 3   Bronx    Fieldston  40.895437 -73.905643
# 4   Bronx    Riverdale  40.890834 -73.912585

# %%
{
    "tags":[
        "remove-cell",
    ]
}

newyork_data.shape
# Out:
# (306, 4)

# %% [markdown]
# ## Displaying the Size of Newyork's Boroughs

# %%
{
    "tags":[
        "hide-input",
    ]
}

clr = "#3186cd"
newyork_data.groupby('Borough')['Neighborhood'].count().plot.bar(figsize=(10,5), color=clr)
plt.title('Neighborhoods per Borough: NYC', fontsize = 16)
plt.xlabel('Borough', fontsize = 12)
plt.ylabel('No. Neighborhoods',fontsize = 12)
plt.xticks(rotation = 'horizontal')
plt.show()

# %% [markdown]
# ### Queens is the largest Borough with more than 80 Neighborhoods. Brooklyn, the second largest Borough account almost 70 Neighborhoods. Manhattan is the smallest with about 40 Neighborhoods.

# %% [markdown]
# ## Locating using Foursquare

# %%
{
    "tags":[
        "remove-input",
    ]
}

CLIENT_ID = 'N5FHYAAPJ40G5EWXDZ5CPPENEPTY53H4XIEY4U5BNVCV5FI1'
CLIENT_SECRET = 'PR31X0GSWRT2IL0WIWXSYYSWGO1MEUJTXG4ZV0BFBVCOB5ZI'
VERSION = '20210215'
LIMIT = 30

# %% [markdown]
# ## French restaurants located

# %%
{
    "tags":[
        "remove-cell",
    ]
}

# French restaurants
column_names=['Borough', 'Neighborhood', 'ID','Name']
french_rest_ny=pd.DataFrame(columns=column_names)
count=1
for row in newyork_data.values.tolist():
    Borough, Neighborhood, Latitude, Longitude=row
    venues = get_venues(Latitude,Longitude)
    french_rest=venues[venues['Category']=='French Restaurant']   
    print('(',count,'/',len(newyork_data),')','French Resturants in '+Neighborhood+', '+Borough+':'+str(len(french_rest)))
    print(row)
    for rest_detail in french_rest.values.tolist():
        id, name , category=rest_detail
        french_rest_ny = french_rest_ny.append({'Borough': Borough,
                                                'Neighborhood': Neighborhood, 
                                                'ID': id,
                                                'Name' : name
                                               }, ignore_index=True)
    count+=1
# Out:
# ( 1 / 306 ) French Resturants in Wakefield, Bronx:0
# ['Bronx', 'Wakefield', 40.89470517661, -73.84720052054902]
# ( 2 / 306 ) French Resturants in Co-op City, Bronx:0
# ['Bronx', 'Co-op City', 40.87429419303012, -73.82993910812398]
# ( 3 / 306 ) French Resturants in Eastchester, Bronx:0
# ['Bronx', 'Eastchester', 40.887555677350775, -73.82780644716412]
# ( 4 / 306 ) French Resturants in Fieldston, Bronx:0
# ['Bronx', 'Fieldston', 40.89543742690383, -73.90564259591682]
# ( 5 / 306 ) French Resturants in Riverdale, Bronx:0
# ['Bronx', 'Riverdale', 40.890834493891305, -73.9125854610857]
# ( 6 / 306 ) French Resturants in Kingsbridge, Bronx:0
# ['Bronx', 'Kingsbridge', 40.88168737120521, -73.90281798724604]
# ( 7 / 306 ) French Resturants in Marble Hill, Manhattan:0
# ['Manhattan', 'Marble Hill', 40.87655077879964, -73.91065965862981]
# ( 8 / 306 ) French Resturants in Woodlawn, Bronx:0
# ['Bronx', 'Woodlawn', 40.89827261213805, -73.86731496814176]
# ( 9 / 306 ) French Resturants in Norwood, Bronx:0
# ['Bronx', 'Norwood', 40.87722415599446, -73.8793907395681]
# ( 10 / 306 ) French Resturants in Williamsbridge, Bronx:0
# ['Bronx', 'Williamsbridge', 40.88103887819211, -73.85744642974207]
# ( 11 / 306 ) French Resturants in Baychester, Bronx:0
# ['Bronx', 'Baychester', 40.866858107252696, -73.83579759808117]
# ( 12 / 306 ) French Resturants in Pelham Parkway, Bronx:0
# ['Bronx', 'Pelham Parkway', 40.85741349808865, -73.85475564017999]
# ( 13 / 306 ) French Resturants in City Island, Bronx:1
# ['Bronx', 'City Island', 40.84724670491813, -73.78648845267413]
# ( 14 / 306 ) French Resturants in Bedford Park, Bronx:0
# ['Bronx', 'Bedford Park', 40.870185164975325, -73.8855121841913]
# ( 15 / 306 ) French Resturants in University Heights, Bronx:0
# ['Bronx', 'University Heights', 40.85572707719664, -73.9104159619131]
# ( 16 / 306 ) French Resturants in Morris Heights, Bronx:0
# ['Bronx', 'Morris Heights', 40.84789792606271, -73.91967159119565]
# ( 17 / 306 ) French Resturants in Fordham, Bronx:0
# ['Bronx', 'Fordham', 40.86099679638654, -73.89642655981623]
# ( 18 / 306 ) French Resturants in East Tremont, Bronx:0
# ['Bronx', 'East Tremont', 40.84269615786053, -73.88735617532338]
# ( 19 / 306 ) French Resturants in West Farms, Bronx:0
# ['Bronx', 'West Farms', 40.83947505672653, -73.87774474910545]
# ( 20 / 306 ) French Resturants in High  Bridge, Bronx:0
# ['Bronx', 'High  Bridge', 40.836623010706056, -73.9261020935813]
# ( 21 / 306 ) French Resturants in Melrose, Bronx:0
# ['Bronx', 'Melrose', 40.819754370594936, -73.90942160757436]
# ( 22 / 306 ) French Resturants in Mott Haven, Bronx:0
# ['Bronx', 'Mott Haven', 40.80623874935177, -73.91609987487575]
# ( 23 / 306 ) French Resturants in Port Morris, Bronx:0
# ['Bronx', 'Port Morris', 40.801663627756206, -73.91322139386135]
# ( 24 / 306 ) French Resturants in Longwood, Bronx:0
# ['Bronx', 'Longwood', 40.81509904545822, -73.8957882009446]
# ( 25 / 306 ) French Resturants in Hunts Point, Bronx:0
# ['Bronx', 'Hunts Point', 40.80972987938709, -73.88331505955291]
# ( 26 / 306 ) French Resturants in Morrisania, Bronx:0
# ['Bronx', 'Morrisania', 40.82359198585534, -73.90150648943059]
# ( 27 / 306 ) French Resturants in Soundview, Bronx:0
# ['Bronx', 'Soundview', 40.821012197914015, -73.86574609554924]
# ( 28 / 306 ) French Resturants in Clason Point, Bronx:0
# ['Bronx', 'Clason Point', 40.80655112003589, -73.85414416189266]
# ( 29 / 306 ) French Resturants in Throgs Neck, Bronx:0
# ['Bronx', 'Throgs Neck', 40.81510925804005, -73.81635002158441]
# ( 30 / 306 ) French Resturants in Country Club, Bronx:0
# ['Bronx', 'Country Club', 40.844245936947374, -73.8240992675385]
# ( 31 / 306 ) French Resturants in Parkchester, Bronx:0
# ['Bronx', 'Parkchester', 40.837937822267286, -73.85600310535783]
# ( 32 / 306 ) French Resturants in Westchester Square, Bronx:0
# ['Bronx', 'Westchester Square', 40.8406194964327, -73.84219407604444]
# ( 33 / 306 ) French Resturants in Van Nest, Bronx:0
# ['Bronx', 'Van Nest', 40.84360847124718, -73.8662991807561]
# ( 34 / 306 ) French Resturants in Morris Park, Bronx:0
# ['Bronx', 'Morris Park', 40.847549063536334, -73.85040178030421]
# ( 35 / 306 ) French Resturants in Belmont, Bronx:0
# ['Bronx', 'Belmont', 40.85727710073895, -73.88845196134804]
# ( 36 / 306 ) French Resturants in Spuyten Duyvil, Bronx:0
# ['Bronx', 'Spuyten Duyvil', 40.88139497727086, -73.91719048210393]
# ( 37 / 306 ) French Resturants in North Riverdale, Bronx:0
# ['Bronx', 'North Riverdale', 40.90854282950666, -73.90453054908927]
# ( 38 / 306 ) French Resturants in Pelham Bay, Bronx:0
# ['Bronx', 'Pelham Bay', 40.85064140940335, -73.8320737824047]
# ( 39 / 306 ) French Resturants in Schuylerville, Bronx:0
# ['Bronx', 'Schuylerville', 40.82657951686922, -73.82620275994073]
# ( 40 / 306 ) French Resturants in Edgewater Park, Bronx:0
# ['Bronx', 'Edgewater Park', 40.821986118163494, -73.81388514428619]
# ( 41 / 306 ) French Resturants in Castle Hill, Bronx:0
# ['Bronx', 'Castle Hill', 40.819014376988314, -73.84802729582735]
# ( 42 / 306 ) French Resturants in Olinville, Bronx:0
# ['Bronx', 'Olinville', 40.87137078192371, -73.86332361652777]
# ( 43 / 306 ) French Resturants in Pelham Gardens, Bronx:0
# ['Bronx', 'Pelham Gardens', 40.86296562477998, -73.84161194831223]
# ( 44 / 306 ) French Resturants in Concourse, Bronx:0
# ['Bronx', 'Concourse', 40.83428380733851, -73.91558941773444]
# ( 45 / 306 ) French Resturants in Unionport, Bronx:0
# ['Bronx', 'Unionport', 40.82977429787161, -73.85053524451935]
# ( 46 / 306 ) French Resturants in Edenwald, Bronx:0
# ['Bronx', 'Edenwald', 40.88456130303732, -73.84808271877168]
# ( 47 / 306 ) French Resturants in Bay Ridge, Brooklyn:0
# ['Brooklyn', 'Bay Ridge', 40.625801065010656, -74.03062069353813]
# ( 48 / 306 ) French Resturants in Bensonhurst, Brooklyn:0
# ['Brooklyn', 'Bensonhurst', 40.61100890202044, -73.99517998380729]
# ( 49 / 306 ) French Resturants in Sunset Park, Brooklyn:0
# ['Brooklyn', 'Sunset Park', 40.64510294925429, -74.01031618527784]
# ( 50 / 306 ) French Resturants in Greenpoint, Brooklyn:2
# ['Brooklyn', 'Greenpoint', 40.7302009848647, -73.95424093127393]
# ( 51 / 306 ) French Resturants in Gravesend, Brooklyn:0
# ['Brooklyn', 'Gravesend', 40.59526001306593, -73.97347087708445]
# ( 52 / 306 ) French Resturants in Brighton Beach, Brooklyn:0
# ['Brooklyn', 'Brighton Beach', 40.57682506566604, -73.96509448785336]
# ( 53 / 306 ) French Resturants in Sheepshead Bay, Brooklyn:0
# ['Brooklyn', 'Sheepshead Bay', 40.58689012678384, -73.94318640482979]
# ( 54 / 306 ) French Resturants in Manhattan Terrace, Brooklyn:0
# ['Brooklyn', 'Manhattan Terrace', 40.61443251335098, -73.95743840559939]
# ( 55 / 306 ) French Resturants in Flatbush, Brooklyn:0
# ['Brooklyn', 'Flatbush', 40.63632589026677, -73.95840106533903]
# ( 56 / 306 ) French Resturants in Crown Heights, Brooklyn:0
# ['Brooklyn', 'Crown Heights', 40.67082917695294, -73.94329119073582]
# ( 57 / 306 ) French Resturants in East Flatbush, Brooklyn:0
# ['Brooklyn', 'East Flatbush', 40.64171776668961, -73.93610256185836]
# ( 58 / 306 ) French Resturants in Kensington, Brooklyn:0
# ['Brooklyn', 'Kensington', 40.642381958003526, -73.98042110559474]
# ( 59 / 306 ) French Resturants in Windsor Terrace, Brooklyn:1
# ['Brooklyn', 'Windsor Terrace', 40.65694583575104, -73.98007340430172]
# ( 60 / 306 ) French Resturants in Prospect Heights, Brooklyn:0
# ['Brooklyn', 'Prospect Heights', 40.676822262254724, -73.9648592426269]
# ( 61 / 306 ) French Resturants in Brownsville, Brooklyn:0
# ['Brooklyn', 'Brownsville', 40.66394994339755, -73.91023536176607]
# ( 62 / 306 ) French Resturants in Williamsburg, Brooklyn:0
# ['Brooklyn', 'Williamsburg', 40.70714439344251, -73.95811529220927]
# ( 63 / 306 ) French Resturants in Bushwick, Brooklyn:1
# ['Brooklyn', 'Bushwick', 40.69811611017901, -73.92525797487045]
# ( 64 / 306 ) French Resturants in Bedford Stuyvesant, Brooklyn:0
# ['Brooklyn', 'Bedford Stuyvesant', 40.687231607720456, -73.94178488690297]
# ( 65 / 306 ) French Resturants in Brooklyn Heights, Brooklyn:0
# ['Brooklyn', 'Brooklyn Heights', 40.695863722724084, -73.99378225496424]
# ( 66 / 306 ) French Resturants in Cobble Hill, Brooklyn:1
# ['Brooklyn', 'Cobble Hill', 40.687919722485574, -73.99856139218463]
# ( 67 / 306 ) French Resturants in Carroll Gardens, Brooklyn:2
# ['Brooklyn', 'Carroll Gardens', 40.680540231076485, -73.99465372828006]
# ( 68 / 306 ) French Resturants in Red Hook, Brooklyn:0
# ['Brooklyn', 'Red Hook', 40.676253230250886, -74.0127589747356]
# ( 69 / 306 ) French Resturants in Gowanus, Brooklyn:0
# ['Brooklyn', 'Gowanus', 40.673931143187154, -73.99444087145339]
# ( 70 / 306 ) French Resturants in Fort Greene, Brooklyn:2
# ['Brooklyn', 'Fort Greene', 40.68852726018977, -73.97290574369092]
# ( 71 / 306 ) French Resturants in Park Slope, Brooklyn:0
# ['Brooklyn', 'Park Slope', 40.67232052268197, -73.97705030183924]
# ( 72 / 306 ) French Resturants in Cypress Hills, Brooklyn:0
# ['Brooklyn', 'Cypress Hills', 40.68239101144211, -73.87661596457296]
# ( 73 / 306 ) French Resturants in East New York, Brooklyn:0
# ['Brooklyn', 'East New York', 40.669925700847045, -73.88069863917366]
# ( 74 / 306 ) French Resturants in Starrett City, Brooklyn:0
# ['Brooklyn', 'Starrett City', 40.64758905230874, -73.87936970045875]
# ( 75 / 306 ) French Resturants in Canarsie, Brooklyn:0
# ['Brooklyn', 'Canarsie', 40.63556432797428, -73.90209269778966]
# ( 76 / 306 ) French Resturants in Flatlands, Brooklyn:0
# ['Brooklyn', 'Flatlands', 40.630446043757466, -73.92911302644674]
# ( 77 / 306 ) French Resturants in Mill Island, Brooklyn:0
# ['Brooklyn', 'Mill Island', 40.606336421685626, -73.90818571777423]
# ( 78 / 306 ) French Resturants in Manhattan Beach, Brooklyn:0
# ['Brooklyn', 'Manhattan Beach', 40.57791350308657, -73.94353722891886]
# ( 79 / 306 ) French Resturants in Coney Island, Brooklyn:0
# ['Brooklyn', 'Coney Island', 40.57429256471601, -73.98868295821637]
# ( 80 / 306 ) French Resturants in Bath Beach, Brooklyn:0
# ['Brooklyn', 'Bath Beach', 40.59951870282238, -73.99875221443519]
# ( 81 / 306 ) French Resturants in Borough Park, Brooklyn:0
# ['Brooklyn', 'Borough Park', 40.633130512758015, -73.99049823044811]
# ( 82 / 306 ) French Resturants in Dyker Heights, Brooklyn:0
# ['Brooklyn', 'Dyker Heights', 40.619219457722636, -74.01931375636022]
# ( 83 / 306 ) French Resturants in Gerritsen Beach, Brooklyn:0
# ['Brooklyn', 'Gerritsen Beach', 40.590848433902046, -73.93010170691196]
# ( 84 / 306 ) French Resturants in Marine Park, Brooklyn:0
# ['Brooklyn', 'Marine Park', 40.609747779894604, -73.93134404108497]
# ( 85 / 306 ) French Resturants in Clinton Hill, Brooklyn:0
# ['Brooklyn', 'Clinton Hill', 40.693229421881504, -73.96784306216367]
# ( 86 / 306 ) French Resturants in Sea Gate, Brooklyn:0
# ['Brooklyn', 'Sea Gate', 40.57637537890224, -74.0078731120024]
# ( 87 / 306 ) French Resturants in Downtown, Brooklyn:1
# ['Brooklyn', 'Downtown', 40.69084402109802, -73.98346337431099]
# ( 88 / 306 ) French Resturants in Boerum Hill, Brooklyn:2
# ['Brooklyn', 'Boerum Hill', 40.685682912091444, -73.98374824115798]
# ( 89 / 306 ) French Resturants in Prospect Lefferts Gardens, Brooklyn:0
# ['Brooklyn', 'Prospect Lefferts Gardens', 40.658420017469815, -73.95489867077713]
# ( 90 / 306 ) French Resturants in Ocean Hill, Brooklyn:0
# ['Brooklyn', 'Ocean Hill', 40.678402554795355, -73.91306831787395]
# ( 91 / 306 ) French Resturants in City Line, Brooklyn:0
# ['Brooklyn', 'City Line', 40.67856995727479, -73.86797598081334]
# ( 92 / 306 ) French Resturants in Bergen Beach, Brooklyn:0
# ['Brooklyn', 'Bergen Beach', 40.61514955045308, -73.89855633630317]
# ( 93 / 306 ) French Resturants in Midwood, Brooklyn:0
# ['Brooklyn', 'Midwood', 40.62559589869843, -73.95759523489838]
# ( 94 / 306 ) French Resturants in Prospect Park South, Brooklyn:0
# ['Brooklyn', 'Prospect Park South', 40.647008603185185, -73.96261316716048]
# ( 95 / 306 ) French Resturants in Georgetown, Brooklyn:0
# ['Brooklyn', 'Georgetown', 40.62384524478419, -73.91607483951324]
# ( 96 / 306 ) French Resturants in East Williamsburg, Brooklyn:0
# ['Brooklyn', 'East Williamsburg', 40.70849241041548, -73.93885815269195]
# ( 97 / 306 ) French Resturants in North Side, Brooklyn:2
# ['Brooklyn', 'North Side', 40.714822906532014, -73.95880857587582]
# ( 98 / 306 ) French Resturants in South Side, Brooklyn:0
# ['Brooklyn', 'South Side', 40.71086147265064, -73.95800095153331]
# ( 99 / 306 ) French Resturants in Ocean Parkway, Brooklyn:0
# ['Brooklyn', 'Ocean Parkway', 40.61305976667942, -73.96836678035541]
# ( 100 / 306 ) French Resturants in Fort Hamilton, Brooklyn:0
# ['Brooklyn', 'Fort Hamilton', 40.61476812694226, -74.03197914537984]
# ( 101 / 306 ) French Resturants in Chinatown, Manhattan:0
# ['Manhattan', 'Chinatown', 40.71561842231432, -73.99427936255978]
# ( 102 / 306 ) French Resturants in Washington Heights, Manhattan:0
# ['Manhattan', 'Washington Heights', 40.85190252555305, -73.93690027985234]
# ( 103 / 306 ) French Resturants in Inwood, Manhattan:0
# ['Manhattan', 'Inwood', 40.86768396449915, -73.92121042203897]
# ( 104 / 306 ) French Resturants in Hamilton Heights, Manhattan:0
# ['Manhattan', 'Hamilton Heights', 40.823604284811935, -73.94968791883366]
# ( 105 / 306 ) French Resturants in Manhattanville, Manhattan:0
# ['Manhattan', 'Manhattanville', 40.8169344294978, -73.9573853935188]
# ( 106 / 306 ) French Resturants in Central Harlem, Manhattan:2
# ['Manhattan', 'Central Harlem', 40.81597606742414, -73.94321112603905]
# ( 107 / 306 ) French Resturants in East Harlem, Manhattan:1
# ['Manhattan', 'East Harlem', 40.79224946663033, -73.94418223148524]
# ( 108 / 306 ) French Resturants in Upper East Side, Manhattan:3
# ['Manhattan', 'Upper East Side', 40.775638573301805, -73.96050763135]
# ( 109 / 306 ) French Resturants in Yorkville, Manhattan:0
# ['Manhattan', 'Yorkville', 40.775929849884875, -73.94711784471826]
# ( 110 / 306 ) French Resturants in Lenox Hill, Manhattan:1
# ['Manhattan', 'Lenox Hill', 40.76811265828733, -73.9588596881376]
# ( 111 / 306 ) French Resturants in Roosevelt Island, Manhattan:0
# ['Manhattan', 'Roosevelt Island', 40.76215960576283, -73.94916769227953]
# ( 112 / 306 ) French Resturants in Upper West Side, Manhattan:0
# ['Manhattan', 'Upper West Side', 40.787657998534854, -73.97705923630603]
# ( 113 / 306 ) French Resturants in Lincoln Square, Manhattan:1
# ['Manhattan', 'Lincoln Square', 40.77352888942166, -73.98533777001262]
# ( 114 / 306 ) French Resturants in Clinton, Manhattan:2
# ['Manhattan', 'Clinton', 40.75910089146212, -73.99611936309479]
# ( 115 / 306 ) French Resturants in Midtown, Manhattan:2
# ['Manhattan', 'Midtown', 40.75469110270623, -73.98166882730304]
# ( 116 / 306 ) French Resturants in Murray Hill, Manhattan:0
# ['Manhattan', 'Murray Hill', 40.748303077252174, -73.97833207924127]
# ( 117 / 306 ) French Resturants in Chelsea, Manhattan:2
# ['Manhattan', 'Chelsea', 40.744034706747975, -74.00311633472813]
# ( 118 / 306 ) French Resturants in Greenwich Village, Manhattan:3
# ['Manhattan', 'Greenwich Village', 40.72693288536128, -73.99991402945902]
# ( 119 / 306 ) French Resturants in East Village, Manhattan:1
# ['Manhattan', 'East Village', 40.727846777270244, -73.98222616506416]
# ( 120 / 306 ) French Resturants in Lower East Side, Manhattan:1
# ['Manhattan', 'Lower East Side', 40.71780674892765, -73.98089031999291]
# ( 121 / 306 ) French Resturants in Tribeca, Manhattan:0
# ['Manhattan', 'Tribeca', 40.721521967443216, -74.01068328559087]
# ( 122 / 306 ) French Resturants in Little Italy, Manhattan:1
# ['Manhattan', 'Little Italy', 40.71932379395907, -73.99730467208073]
# ( 123 / 306 ) French Resturants in Soho, Manhattan:2
# ['Manhattan', 'Soho', 40.72218384131794, -74.00065666959759]
# ( 124 / 306 ) French Resturants in West Village, Manhattan:3
# ['Manhattan', 'West Village', 40.73443393572434, -74.00617998126812]
# ( 125 / 306 ) French Resturants in Manhattan Valley, Manhattan:0
# ['Manhattan', 'Manhattan Valley', 40.797307041702865, -73.96428617740655]
# ( 126 / 306 ) French Resturants in Morningside Heights, Manhattan:0
# ['Manhattan', 'Morningside Heights', 40.807999738165826, -73.96389627905332]
# ( 127 / 306 ) French Resturants in Gramercy, Manhattan:0
# ['Manhattan', 'Gramercy', 40.737209832715, -73.98137594833541]
# ( 128 / 306 ) French Resturants in Battery Park City, Manhattan:0
# ['Manhattan', 'Battery Park City', 40.71193198394565, -74.01686930508617]
# ( 129 / 306 ) French Resturants in Financial District, Manhattan:1
# ['Manhattan', 'Financial District', 40.70710710727048, -74.0106654452127]
# ( 130 / 306 ) French Resturants in Astoria, Queens:0
# ['Queens', 'Astoria', 40.76850859335492, -73.91565374304234]
# ( 131 / 306 ) French Resturants in Woodside, Queens:0
# ['Queens', 'Woodside', 40.74634908860222, -73.90184166838284]
# ( 132 / 306 ) French Resturants in Jackson Heights, Queens:0
# ['Queens', 'Jackson Heights', 40.75198138007367, -73.88282109164365]
# ( 133 / 306 ) French Resturants in Elmhurst, Queens:0
# ['Queens', 'Elmhurst', 40.744048505122024, -73.88165622288388]
# ( 134 / 306 ) French Resturants in Howard Beach, Queens:0
# ['Queens', 'Howard Beach', 40.65422527738487, -73.8381376460028]
# ( 135 / 306 ) French Resturants in Corona, Queens:0
# ['Queens', 'Corona', 40.74238175015667, -73.85682497345258]
# ( 136 / 306 ) French Resturants in Forest Hills, Queens:0
# ['Queens', 'Forest Hills', 40.72526378216503, -73.84447500788983]
# ( 137 / 306 ) French Resturants in Kew Gardens, Queens:0
# ['Queens', 'Kew Gardens', 40.7051790354148, -73.82981905825703]
# ( 138 / 306 ) French Resturants in Richmond Hill, Queens:0
# ['Queens', 'Richmond Hill', 40.69794731471763, -73.83183321446887]
# ( 139 / 306 ) French Resturants in Flushing, Queens:0
# ['Queens', 'Flushing', 40.76445419697846, -73.83177300329582]
# ( 140 / 306 ) French Resturants in Long Island City, Queens:0
# ['Queens', 'Long Island City', 40.75021734610528, -73.93920223915505]
# ( 141 / 306 ) French Resturants in Sunnyside, Queens:0
# ['Queens', 'Sunnyside', 40.74017628351924, -73.92691617561577]
# ( 142 / 306 ) French Resturants in East Elmhurst, Queens:0
# ['Queens', 'East Elmhurst', 40.76407323883091, -73.86704147658772]
# ( 143 / 306 ) French Resturants in Maspeth, Queens:0
# ['Queens', 'Maspeth', 40.725427374093606, -73.89621713626859]
# ( 144 / 306 ) French Resturants in Ridgewood, Queens:0
# ['Queens', 'Ridgewood', 40.70832315613858, -73.90143517559589]
# ( 145 / 306 ) French Resturants in Glendale, Queens:0
# ['Queens', 'Glendale', 40.70276242967838, -73.87074167435605]
# ( 146 / 306 ) French Resturants in Rego Park, Queens:0
# ['Queens', 'Rego Park', 40.72897409480735, -73.8578268690537]
# ( 147 / 306 ) French Resturants in Woodhaven, Queens:0
# ['Queens', 'Woodhaven', 40.68988687915789, -73.8581104655432]
# ( 148 / 306 ) French Resturants in Ozone Park, Queens:0
# ['Queens', 'Ozone Park', 40.680708468265415, -73.84320266173447]
# ( 149 / 306 ) French Resturants in South Ozone Park, Queens:0
# ['Queens', 'South Ozone Park', 40.66854957767195, -73.80986478649041]
# ( 150 / 306 ) French Resturants in College Point, Queens:0
# ['Queens', 'College Point', 40.784902749260205, -73.84304528896125]
# ( 151 / 306 ) French Resturants in Whitestone, Queens:0
# ['Queens', 'Whitestone', 40.78129076602694, -73.81420216610863]
# ( 152 / 306 ) French Resturants in Bayside, Queens:1
# ['Queens', 'Bayside', 40.76604063281064, -73.7742736306867]
# ( 153 / 306 ) French Resturants in Auburndale, Queens:0
# ['Queens', 'Auburndale', 40.76172954903262, -73.79176243728061]
# ( 154 / 306 ) French Resturants in Little Neck, Queens:0
# ['Queens', 'Little Neck', 40.7708261928267, -73.7388977558074]
# ( 155 / 306 ) French Resturants in Douglaston, Queens:0
# ['Queens', 'Douglaston', 40.76684609790763, -73.7424982072733]
# ( 156 / 306 ) French Resturants in Glen Oaks, Queens:0
# ['Queens', 'Glen Oaks', 40.74944079974332, -73.71548118999145]
# ( 157 / 306 ) French Resturants in Bellerose, Queens:0
# ['Queens', 'Bellerose', 40.72857318176675, -73.72012814826903]
# ( 158 / 306 ) French Resturants in Kew Gardens Hills, Queens:0
# ['Queens', 'Kew Gardens Hills', 40.722578244228046, -73.82087764933566]
# ( 159 / 306 ) French Resturants in Fresh Meadows, Queens:0
# ['Queens', 'Fresh Meadows', 40.7343944653313, -73.78271337003264]
# ( 160 / 306 ) French Resturants in Briarwood, Queens:0
# ['Queens', 'Briarwood', 40.71093547252271, -73.81174822458634]
# ( 161 / 306 ) French Resturants in Jamaica Center, Queens:0
# ['Queens', 'Jamaica Center', 40.70465736068717, -73.79690165888289]
# ( 162 / 306 ) French Resturants in Oakland Gardens, Queens:0
# ['Queens', 'Oakland Gardens', 40.74561857141855, -73.75494976234332]
# ( 163 / 306 ) French Resturants in Queens Village, Queens:0
# ['Queens', 'Queens Village', 40.718893092167356, -73.73871484578424]
# ( 164 / 306 ) French Resturants in Hollis, Queens:0
# ['Queens', 'Hollis', 40.71124344191904, -73.75925009335594]
# ( 165 / 306 ) French Resturants in South Jamaica, Queens:0
# ['Queens', 'South Jamaica', 40.696911253789885, -73.7904261313554]
# ( 166 / 306 ) French Resturants in St. Albans, Queens:0
# ['Queens', 'St. Albans', 40.69444538522359, -73.75867603727717]
# ( 167 / 306 ) French Resturants in Rochdale, Queens:0
# ['Queens', 'Rochdale', 40.67521139591733, -73.77258787620906]
# ( 168 / 306 ) French Resturants in Springfield Gardens, Queens:0
# ['Queens', 'Springfield Gardens', 40.666230490368584, -73.76042092682287]
# ( 169 / 306 ) French Resturants in Cambria Heights, Queens:0
# ['Queens', 'Cambria Heights', 40.692774639160845, -73.73526873708026]
# ( 170 / 306 ) French Resturants in Rosedale, Queens:0
# ['Queens', 'Rosedale', 40.659816433428084, -73.73526079428278]
# ( 171 / 306 ) French Resturants in Far Rockaway, Queens:0
# ['Queens', 'Far Rockaway', 40.603134432500894, -73.75497968043872]
# ( 172 / 306 ) French Resturants in Broad Channel, Queens:0
# ['Queens', 'Broad Channel', 40.60302658351238, -73.8200548911032]
# ( 173 / 306 ) French Resturants in Breezy Point, Queens:0
# ['Queens', 'Breezy Point', 40.55740128845452, -73.92551196994168]
# ( 174 / 306 ) French Resturants in Steinway, Queens:0
# ['Queens', 'Steinway', 40.775923015642896, -73.90228960391673]
# ( 175 / 306 ) French Resturants in Beechhurst, Queens:0
# ['Queens', 'Beechhurst', 40.79278140360048, -73.80436451720988]
# ( 176 / 306 ) French Resturants in Bay Terrace, Queens:0
# ['Queens', 'Bay Terrace', 40.782842806245554, -73.7768022262158]
# ( 177 / 306 ) French Resturants in Edgemere, Queens:0
# ['Queens', 'Edgemere', 40.595641807368494, -73.77613282391705]
# ( 178 / 306 ) French Resturants in Arverne, Queens:0
# ['Queens', 'Arverne', 40.58914394372971, -73.79199233136943]
# ( 179 / 306 ) French Resturants in Rockaway Beach, Queens:0
# ['Queens', 'Rockaway Beach', 40.582801696845586, -73.82236121088751]
# ( 180 / 306 ) French Resturants in Neponsit, Queens:0
# ['Queens', 'Neponsit', 40.572036730217015, -73.85754672410827]
# ( 181 / 306 ) French Resturants in Murray Hill, Queens:0
# ['Queens', 'Murray Hill', 40.764126122614066, -73.81276269135866]
# ( 182 / 306 ) French Resturants in Floral Park, Queens:0
# ['Queens', 'Floral Park', 40.741378421945434, -73.70884705889246]
# ( 183 / 306 ) French Resturants in Holliswood, Queens:0
# ['Queens', 'Holliswood', 40.7209572076444, -73.76714166714729]
# ( 184 / 306 ) French Resturants in Jamaica Estates, Queens:0
# ['Queens', 'Jamaica Estates', 40.71680483014613, -73.7872269693666]
# ( 185 / 306 ) French Resturants in Queensboro Hill, Queens:0
# ['Queens', 'Queensboro Hill', 40.7445723092867, -73.82580915110559]
# ( 186 / 306 ) French Resturants in Hillcrest, Queens:0
# ['Queens', 'Hillcrest', 40.723824901829204, -73.79760300912672]
# ( 187 / 306 ) French Resturants in Ravenswood, Queens:0
# ['Queens', 'Ravenswood', 40.761704526054146, -73.93157506072878]
# ( 188 / 306 ) French Resturants in Lindenwood, Queens:0
# ['Queens', 'Lindenwood', 40.66391841925139, -73.84963782402441]
# ( 189 / 306 ) French Resturants in Laurelton, Queens:0
# ['Queens', 'Laurelton', 40.66788389660247, -73.74025607989822]
# ( 190 / 306 ) French Resturants in Lefrak City, Queens:0
# ['Queens', 'Lefrak City', 40.736074570830795, -73.8625247141374]
# ( 191 / 306 ) French Resturants in Belle Harbor, Queens:0
# ['Queens', 'Belle Harbor', 40.57615556543109, -73.8540175039252]
# ( 192 / 306 ) French Resturants in Rockaway Park, Queens:0
# ['Queens', 'Rockaway Park', 40.58034295646131, -73.84153370226186]
# ( 193 / 306 ) French Resturants in Somerville, Queens:0
# ['Queens', 'Somerville', 40.59771061565768, -73.79664750844047]
# ( 194 / 306 ) French Resturants in Brookville, Queens:0
# ['Queens', 'Brookville', 40.66000322733613, -73.75175310731153]
# ( 195 / 306 ) French Resturants in Bellaire, Queens:0
# ['Queens', 'Bellaire', 40.73301404027834, -73.73889198912481]
# ( 196 / 306 ) French Resturants in North Corona, Queens:0
# ['Queens', 'North Corona', 40.7540709990489, -73.85751790676447]
# ( 197 / 306 ) French Resturants in Forest Hills Gardens, Queens:0
# ['Queens', 'Forest Hills Gardens', 40.7146110815117, -73.8410221123401]
# ( 198 / 306 ) French Resturants in St. George, Staten Island:0
# ['Staten Island', 'St. George', 40.6449815710044, -74.07935312512797]
# ( 199 / 306 ) French Resturants in New Brighton, Staten Island:0
# ['Staten Island', 'New Brighton', 40.64061455913511, -74.08701650516625]
# ( 200 / 306 ) French Resturants in Stapleton, Staten Island:0
# ['Staten Island', 'Stapleton', 40.62692762538176, -74.07790192660066]
# ( 201 / 306 ) French Resturants in Rosebank, Staten Island:0
# ['Staten Island', 'Rosebank', 40.61530494652761, -74.06980526716141]
# ( 202 / 306 ) French Resturants in West Brighton, Staten Island:0
# ['Staten Island', 'West Brighton', 40.63187892654607, -74.1071817826561]
# ( 203 / 306 ) French Resturants in Grymes Hill, Staten Island:0
# ['Staten Island', 'Grymes Hill', 40.624184791313006, -74.08724819983729]
# ( 204 / 306 ) French Resturants in Todt Hill, Staten Island:0
# ['Staten Island', 'Todt Hill', 40.59706851814673, -74.1113288180088]
# ( 205 / 306 ) French Resturants in South Beach, Staten Island:0
# ['Staten Island', 'South Beach', 40.58024741350956, -74.0795529253982]
# ( 206 / 306 ) French Resturants in Port Richmond, Staten Island:0
# ['Staten Island', 'Port Richmond', 40.63366930554365, -74.12943426797008]
# ( 207 / 306 ) French Resturants in Mariner's Harbor, Staten Island:0
# ['Staten Island', "Mariner's Harbor", 40.632546390481124, -74.15008537046981]
# ( 208 / 306 ) French Resturants in Port Ivory, Staten Island:0
# ['Staten Island', 'Port Ivory', 40.63968297845542, -74.17464532993542]
# ( 209 / 306 ) French Resturants in Castleton Corners, Staten Island:0
# ['Staten Island', 'Castleton Corners', 40.61333593766742, -74.11918058534842]
# ( 210 / 306 ) French Resturants in New Springville, Staten Island:0
# ['Staten Island', 'New Springville', 40.594252379161695, -74.16496031329827]
# ( 211 / 306 ) French Resturants in Travis, Staten Island:0
# ['Staten Island', 'Travis', 40.58631375103281, -74.19073717538116]
# ( 212 / 306 ) French Resturants in New Dorp, Staten Island:0
# ['Staten Island', 'New Dorp', 40.57257231820632, -74.1164794360638]
# ( 213 / 306 ) French Resturants in Oakwood, Staten Island:0
# ['Staten Island', 'Oakwood', 40.5584622432888, -74.12156593771896]
# ( 214 / 306 ) French Resturants in Great Kills, Staten Island:0
# ['Staten Island', 'Great Kills', 40.549480228713605, -74.14932381490992]
# ( 215 / 306 ) French Resturants in Eltingville, Staten Island:0
# ['Staten Island', 'Eltingville', 40.542230747450745, -74.1643308041936]
# ( 216 / 306 ) French Resturants in Annadale, Staten Island:0
# ['Staten Island', 'Annadale', 40.53811417474507, -74.17854866165878]
# ( 217 / 306 ) French Resturants in Woodrow, Staten Island:0
# ['Staten Island', 'Woodrow', 40.541967622888755, -74.20524582480326]
# ( 218 / 306 ) French Resturants in Tottenville, Staten Island:0
# ['Staten Island', 'Tottenville', 40.50533376115642, -74.24656934235283]
# ( 219 / 306 ) French Resturants in Tompkinsville, Staten Island:0
# ['Staten Island', 'Tompkinsville', 40.637316067110326, -74.08055351790115]
# ( 220 / 306 ) French Resturants in Silver Lake, Staten Island:0
# ['Staten Island', 'Silver Lake', 40.61919310792676, -74.09629029235458]
# ( 221 / 306 ) French Resturants in Sunnyside, Staten Island:0
# ['Staten Island', 'Sunnyside', 40.61276015756489, -74.0971255217853]
# ( 222 / 306 ) French Resturants in Ditmas Park, Brooklyn:0
# ['Brooklyn', 'Ditmas Park', 40.643675183340974, -73.96101312466779]
# ( 223 / 306 ) French Resturants in Wingate, Brooklyn:0
# ['Brooklyn', 'Wingate', 40.66094656188111, -73.93718680559314]
# ( 224 / 306 ) French Resturants in Rugby, Brooklyn:0
# ['Brooklyn', 'Rugby', 40.655572313280764, -73.92688212616955]
# ( 225 / 306 ) French Resturants in Park Hill, Staten Island:0
# ['Staten Island', 'Park Hill', 40.60919044434558, -74.08015734936296]
# ( 226 / 306 ) French Resturants in Westerleigh, Staten Island:0
# ['Staten Island', 'Westerleigh', 40.62109047275409, -74.13304143951704]
# ( 227 / 306 ) French Resturants in Graniteville, Staten Island:0
# ['Staten Island', 'Graniteville', 40.620171512231884, -74.15315246387762]
# ( 228 / 306 ) French Resturants in Arlington, Staten Island:0
# ['Staten Island', 'Arlington', 40.63532509911492, -74.16510420241124]
# ( 229 / 306 ) French Resturants in Arrochar, Staten Island:0
# ['Staten Island', 'Arrochar', 40.596312571276734, -74.06712363225574]
# ( 230 / 306 ) French Resturants in Grasmere, Staten Island:0
# ['Staten Island', 'Grasmere', 40.59826835959991, -74.0766743627905]
# ( 231 / 306 ) French Resturants in Old Town, Staten Island:0
# ['Staten Island', 'Old Town', 40.59632891379513, -74.08751118005578]
# ( 232 / 306 ) French Resturants in Dongan Hills, Staten Island:0
# ['Staten Island', 'Dongan Hills', 40.588672948199275, -74.09639905312521]
# ( 233 / 306 ) French Resturants in Midland Beach, Staten Island:0
# ['Staten Island', 'Midland Beach', 40.57352690574283, -74.09348266303591]
# ( 234 / 306 ) French Resturants in Grant City, Staten Island:0
# ['Staten Island', 'Grant City', 40.57621558711788, -74.10585598545434]
# ( 235 / 306 ) French Resturants in New Dorp Beach, Staten Island:0
# ['Staten Island', 'New Dorp Beach', 40.56425549307335, -74.10432707469124]
# ( 236 / 306 ) French Resturants in Bay Terrace, Staten Island:0
# ['Staten Island', 'Bay Terrace', 40.55398800858462, -74.13916622175768]
# ( 237 / 306 ) French Resturants in Huguenot, Staten Island:0
# ['Staten Island', 'Huguenot', 40.531911920489605, -74.19174105747814]
# ( 238 / 306 ) French Resturants in Pleasant Plains, Staten Island:0
# ['Staten Island', 'Pleasant Plains', 40.524699376118136, -74.21983106616777]
# ( 239 / 306 ) French Resturants in Butler Manor, Staten Island:0
# ['Staten Island', 'Butler Manor', 40.50608165346305, -74.22950350260027]
# ( 240 / 306 ) French Resturants in Charleston, Staten Island:0
# ['Staten Island', 'Charleston', 40.53053148283314, -74.23215775896526]
# ( 241 / 306 ) French Resturants in Rossville, Staten Island:0
# ['Staten Island', 'Rossville', 40.54940400650072, -74.21572851113952]
# ( 242 / 306 ) French Resturants in Arden Heights, Staten Island:0
# ['Staten Island', 'Arden Heights', 40.54928582278321, -74.18588674583893]
# ( 243 / 306 ) French Resturants in Greenridge, Staten Island:0
# ['Staten Island', 'Greenridge', 40.555295236173194, -74.17079414786092]
# ( 244 / 306 ) French Resturants in Heartland Village, Staten Island:0
# ['Staten Island', 'Heartland Village', 40.58913894875281, -74.15902208156601]
# ( 245 / 306 ) French Resturants in Chelsea, Staten Island:0
# ['Staten Island', 'Chelsea', 40.59472602746295, -74.1895604551969]
# ( 246 / 306 ) French Resturants in Bloomfield, Staten Island:0
# ['Staten Island', 'Bloomfield', 40.60577868452358, -74.18725638381567]
# ( 247 / 306 ) French Resturants in Bulls Head, Staten Island:0
# ['Staten Island', 'Bulls Head', 40.6095918004203, -74.15940948657122]
# ( 248 / 306 ) French Resturants in Carnegie Hill, Manhattan:1
# ['Manhattan', 'Carnegie Hill', 40.7826825671257, -73.95325646837112]
# ( 249 / 306 ) French Resturants in Noho, Manhattan:3
# ['Manhattan', 'Noho', 40.72325901885768, -73.98843368023597]
# ( 250 / 306 ) French Resturants in Civic Center, Manhattan:2
# ['Manhattan', 'Civic Center', 40.71522892046282, -74.00541529873355]
# ( 251 / 306 ) French Resturants in Midtown South, Manhattan:1
# ['Manhattan', 'Midtown South', 40.7485096643122, -73.98871313285247]
# ( 252 / 306 ) French Resturants in Richmond Town, Staten Island:0
# ['Staten Island', 'Richmond Town', 40.56960594275505, -74.1340572986257]
# ( 253 / 306 ) French Resturants in Shore Acres, Staten Island:0
# ['Staten Island', 'Shore Acres', 40.60971934079284, -74.06667766061771]
# ( 254 / 306 ) French Resturants in Clifton, Staten Island:0
# ['Staten Island', 'Clifton', 40.61917845202843, -74.072642445484]
# ( 255 / 306 ) French Resturants in Concord, Staten Island:0
# ['Staten Island', 'Concord', 40.6044731896879, -74.08402364740358]
# ( 256 / 306 ) French Resturants in Emerson Hill, Staten Island:0
# ['Staten Island', 'Emerson Hill', 40.606794394801, -74.09776206972522]
# ( 257 / 306 ) French Resturants in Randall Manor, Staten Island:0
# ['Staten Island', 'Randall Manor', 40.63563000681151, -74.09805062373887]
# ( 258 / 306 ) French Resturants in Howland Hook, Staten Island:0
# ['Staten Island', 'Howland Hook', 40.63843283794795, -74.18622331749823]
# ( 259 / 306 ) French Resturants in Elm Park, Staten Island:0
# ['Staten Island', 'Elm Park', 40.630146741193826, -74.1418167896889]
# ( 260 / 306 ) French Resturants in Remsen Village, Brooklyn:0
# ['Brooklyn', 'Remsen Village', 40.652117451793494, -73.91665331978048]
# ( 261 / 306 ) French Resturants in New Lots, Brooklyn:0
# ['Brooklyn', 'New Lots', 40.6627442796966, -73.88511776379292]
# ( 262 / 306 ) French Resturants in Paerdegat Basin, Brooklyn:0
# ['Brooklyn', 'Paerdegat Basin', 40.63131755039667, -73.90233474295836]
# ( 263 / 306 ) French Resturants in Mill Basin, Brooklyn:0
# ['Brooklyn', 'Mill Basin', 40.61597423962336, -73.91515391550404]
# ( 264 / 306 ) French Resturants in Jamaica Hills, Queens:0
# ['Queens', 'Jamaica Hills', 40.71145964370482, -73.79646462081593]
# ( 265 / 306 ) French Resturants in Utopia, Queens:0
# ['Queens', 'Utopia', 40.73350025429757, -73.79671678028349]
# ( 266 / 306 ) French Resturants in Pomonok, Queens:0
# ['Queens', 'Pomonok', 40.73493618075478, -73.80486120040537]
# ( 267 / 306 ) French Resturants in Astoria Heights, Queens:0
# ['Queens', 'Astoria Heights', 40.7703173929982, -73.89467996270574]
# ( 268 / 306 ) French Resturants in Claremont Village, Bronx:0
# ['Bronx', 'Claremont Village', 40.83142834161548, -73.90119903387667]
# ( 269 / 306 ) French Resturants in Concourse Village, Bronx:0
# ['Bronx', 'Concourse Village', 40.824780490842905, -73.91584652759009]
# ( 270 / 306 ) French Resturants in Mount Eden, Bronx:0
# ['Bronx', 'Mount Eden', 40.84382617671654, -73.91655551964419]
# ( 271 / 306 ) French Resturants in Mount Hope, Bronx:0
# ['Bronx', 'Mount Hope', 40.84884160724665, -73.90829930881988]
# ( 272 / 306 ) French Resturants in Sutton Place, Manhattan:1
# ['Manhattan', 'Sutton Place', 40.76028033131374, -73.96355614094303]
# ( 273 / 306 ) French Resturants in Hunters Point, Queens:0
# ['Queens', 'Hunters Point', 40.743414090073536, -73.95386782130745]
# ( 274 / 306 ) French Resturants in Turtle Bay, Manhattan:1
# ['Manhattan', 'Turtle Bay', 40.75204236950722, -73.96770824581834]
# ( 275 / 306 ) French Resturants in Tudor City, Manhattan:0
# ['Manhattan', 'Tudor City', 40.746917410740195, -73.97121928722265]
# ( 276 / 306 ) French Resturants in Stuyvesant Town, Manhattan:0
# ['Manhattan', 'Stuyvesant Town', 40.73099955477061, -73.97405170469203]
# ( 277 / 306 ) French Resturants in Flatiron, Manhattan:0
# ['Manhattan', 'Flatiron', 40.739673047638426, -73.9909471052826]
# ( 278 / 306 ) French Resturants in Sunnyside Gardens, Queens:2
# ['Queens', 'Sunnyside Gardens', 40.74565180608076, -73.91819286431682]
# ( 279 / 306 ) French Resturants in Blissville, Queens:0
# ['Queens', 'Blissville', 40.73725071694497, -73.93244235260178]
# ( 280 / 306 ) French Resturants in Fulton Ferry, Brooklyn:0
# ['Brooklyn', 'Fulton Ferry', 40.70328109093014, -73.99550751888415]
# ( 281 / 306 ) French Resturants in Vinegar Hill, Brooklyn:0
# ['Brooklyn', 'Vinegar Hill', 40.70332149882874, -73.98111603592393]
# ( 282 / 306 ) French Resturants in Weeksville, Brooklyn:0
# ['Brooklyn', 'Weeksville', 40.67503986503237, -73.93053108817338]
# ( 283 / 306 ) French Resturants in Broadway Junction, Brooklyn:0
# ['Brooklyn', 'Broadway Junction', 40.67786104769531, -73.90331684852599]
# ( 284 / 306 ) French Resturants in Dumbo, Brooklyn:0
# ['Brooklyn', 'Dumbo', 40.70317632822692, -73.9887528074504]
# ( 285 / 306 ) French Resturants in Manor Heights, Staten Island:0
# ['Staten Island', 'Manor Heights', 40.60180957631444, -74.12059399718001]
# ( 286 / 306 ) French Resturants in Willowbrook, Staten Island:0
# ['Staten Island', 'Willowbrook', 40.60370692627371, -74.13208447484298]
# ( 287 / 306 ) French Resturants in Sandy Ground, Staten Island:0
# ['Staten Island', 'Sandy Ground', 40.541139922091766, -74.21776636068567]
# ( 288 / 306 ) French Resturants in Egbertville, Staten Island:0
# ['Staten Island', 'Egbertville', 40.579118742961214, -74.12727240604946]
# ( 289 / 306 ) French Resturants in Roxbury, Queens:0
# ['Queens', 'Roxbury', 40.56737588957032, -73.89213760232822]
# ( 290 / 306 ) French Resturants in Homecrest, Brooklyn:0
# ['Brooklyn', 'Homecrest', 40.598525095137255, -73.95918459428702]
# ( 291 / 306 ) French Resturants in Middle Village, Queens:0
# ['Queens', 'Middle Village', 40.716414511158185, -73.88114319200604]
# ( 292 / 306 ) French Resturants in Prince's Bay, Staten Island:0
# ['Staten Island', "Prince's Bay", 40.52626406734812, -74.20152556457658]
# ( 293 / 306 ) French Resturants in Lighthouse Hill, Staten Island:0
# ['Staten Island', 'Lighthouse Hill', 40.57650629379489, -74.13792663771568]
# ( 294 / 306 ) French Resturants in Richmond Valley, Staten Island:0
# ['Staten Island', 'Richmond Valley', 40.51954145748909, -74.22957080626941]
# ( 295 / 306 ) French Resturants in Malba, Queens:0
# ['Queens', 'Malba', 40.79060155670148, -73.82667757138641]
# ( 296 / 306 ) French Resturants in Highland Park, Brooklyn:0
# ['Brooklyn', 'Highland Park', 40.6819989345173, -73.890345709872]
# ( 297 / 306 ) French Resturants in Madison, Brooklyn:0
# ['Brooklyn', 'Madison', 40.60937770113766, -73.94841515328893]
# ( 298 / 306 ) French Resturants in Bronxdale, Bronx:0
# ['Bronx', 'Bronxdale', 40.85272297633017, -73.86172577555115]
# ( 299 / 306 ) French Resturants in Allerton, Bronx:0
# ['Bronx', 'Allerton', 40.86578787802982, -73.85931863221647]
# ( 300 / 306 ) French Resturants in Kingsbridge Heights, Bronx:0
# ['Bronx', 'Kingsbridge Heights', 40.8703923914147, -73.90152264513144]
# ( 301 / 306 ) French Resturants in Erasmus, Brooklyn:0
# ['Brooklyn', 'Erasmus', 40.64692606658579, -73.94817709920184]
# ( 302 / 306 ) French Resturants in Hudson Yards, Manhattan:0
# ['Manhattan', 'Hudson Yards', 40.75665808227519, -74.00011136202637]
# ( 303 / 306 ) French Resturants in Hammels, Queens:0
# ['Queens', 'Hammels', 40.58733774018741, -73.80553002968718]
# ( 304 / 306 ) French Resturants in Bayswater, Queens:0
# ['Queens', 'Bayswater', 40.611321691283834, -73.76596781445627]
# ( 305 / 306 ) French Resturants in Queensbridge, Queens:0
# ['Queens', 'Queensbridge', 40.756091297094706, -73.94563070334091]
# ( 306 / 306 ) French Resturants in Fox Hills, Staten Island:0
# ['Staten Island', 'Fox Hills', 40.61731079252983, -74.08173992211962]

# %%
{
    "tags":[
        "remove-cell",
    ]
}

# Save the information to a .csv file
french_rest_ny.to_csv('french_rest_ny_tocsv1.csv', index=False)

# %%
{
    "tags":[
        "hide-input",
    ]
}

french_rest_ny = pd.read_csv('french_rest_ny_tocsv1.csv')
french_rest_ny.head()
# Out:
#     Borough     Neighborhood                        ID                   Name
# 0     Bronx      City Island  4d7aa83ee540f04d66ba16dc              Bistro SK
# 1  Brooklyn       Greenpoint  5bf358689fca56002c251a87                Citroën
# 2  Brooklyn       Greenpoint  4bcf1883c564ef3ba33beff0               Le Gamin
# 3  Brooklyn  Windsor Terrace  4aee2d5cf964a520b7d221e3  Le P'tit Paris Bistro
# 4  Brooklyn         Bushwick  55e47d26498e44d12c7c004e              Le Garage

# %% [markdown]
# ### France is always in the top 10 countries for the quality of their food. It's especially known for its finest cookery. Despite of their culinary skills, french cuisine seems to have trouble penetrating the thriving catering market in NYC. Only few Neighborhoods can boast the presence of french restaurants. The tables above and below show that there is only 53 restaurants in the entire NYC.

# %%
{
    "tags":[
        "hide-input",
    ]
}

french_rest_ny.tail()
# Out:
#       Borough       Neighborhood                        ID             Name
# 48  Manhattan      Midtown South  5b06b57962845c00242fb6be    Maison Kayser
# 49  Manhattan       Sutton Place  4b70825df964a520e01e2de3   Bistro Vendome
# 50  Manhattan         Turtle Bay  4a64fda8f964a52023c71fe3        Deux Amis
# 51     Queens  Sunnyside Gardens  57f57d5dcd1047e759ea8838      Côté Soleil
# 52     Queens  Sunnyside Gardens  4eceef679a52262b810ab3bd  Bliss 46 Bistro

# %%
{
    "tags":[
        "remove-cell",
    ]
}

french_rest_ny.shape
# Out:
# (53, 4)

# %%
{
    "tags":[
        "hide-input",
    ]
}

french_rest_ny.groupby('Borough')['ID'].count().plot.bar(figsize=(10,5), color = clr)
plt.title('French Resturants per Borough: NYC', fontsize = 15)
plt.xlabel('Borough', fontsize = 15)
plt.ylabel('No.of French Resturants', fontsize=15)
plt.xticks(rotation = 'horizontal')
plt.show()

# %% [markdown]
# ### The distribution of the 53 french restaurants in NYC are as follow: 35 in Manhattan, 14 in Brooklyn 3 are located in Queens; one (Aperitif) in Bayside Neighborhood and two (Cote Soleil and Bliss 46 Bistro) in Sunnyside Gardens. One can see the strong presence of french restaurants in Manhattan as the desire to settle in the niche of the upper class. It's however hard to understan that the largest borough of NYC is only represented by 3 restaurants.

# %%
{
    "tags":[
        "hide-input",
    ]
}

french_rest_ny[french_rest_ny['Borough']=='Queens']
# Out:
#    Borough       Neighborhood                        ID             Name
# 41  Queens            Bayside  54823da3498e2f6041ab87e2          apertif
# 51  Queens  Sunnyside Gardens  57f57d5dcd1047e759ea8838      Côté Soleil
# 52  Queens  Sunnyside Gardens  4eceef679a52262b810ab3bd  Bliss 46 Bistro

# %%
{
    "tags":[
        "hide-input",
    ]
}

french_rest_ny[french_rest_ny['Borough']=='Manhattan']
# Out:
#       Borough        Neighborhood                        ID  \
# 15  Manhattan      Central Harlem  4b80389ff964a520e95d30e3
# 16  Manhattan      Central Harlem  59cc6158c0af57432b9fd02b
# 17  Manhattan         East Harlem  553c1b00498e7eb81316bf1b
# 18  Manhattan     Upper East Side  3fd66200f964a5207fe91ee3
# 19  Manhattan     Upper East Side  533b5715498ee1e90e846e1d
# 20  Manhattan     Upper East Side  4408540af964a52055301fe3
# 21  Manhattan          Lenox Hill  4f5977dee4b0e4b75e4295d6
# 22  Manhattan      Lincoln Square  478cd1f3f964a520444d1fe3
# 23  Manhattan             Clinton  3fd66200f964a5208de91ee3
# 24  Manhattan             Clinton  3fd66200f964a520b4e81ee3
# 25  Manhattan             Midtown  5552087d498eb30c149f785a
# 26  Manhattan             Midtown  4ab271d1f964a520366b20e3
# 27  Manhattan             Chelsea  44c8e25ef964a520f0351fe3
# 28  Manhattan             Chelsea  5dcf67e642c0140007488570
# 29  Manhattan   Greenwich Village  3fd66200f964a52006e61ee3
# 30  Manhattan   Greenwich Village  50899082e4b0645d657eb40f
# 31  Manhattan   Greenwich Village  515f81d0e4b05d6decaaed19
# 32  Manhattan        East Village  562c3fee498e107a40edabe2
# 33  Manhattan     Lower East Side  5b63aefffe63bd0039d0c297
# 34  Manhattan        Little Italy  57583641498e90001a32e13e
# 35  Manhattan                Soho  3fd66200f964a52070e91ee3
# 36  Manhattan                Soho  57583641498e90001a32e13e
# 37  Manhattan        West Village  4d0bf7e3f29c236ac675bfe7
# 38  Manhattan        West Village  49958ac3f964a52084521fe3
# 39  Manhattan        West Village  3fd66200f964a52006ea1ee3
# 40  Manhattan  Financial District  5a47a5e4e679bc7b226989ca
# 42  Manhattan       Carnegie Hill  4b9d2218f964a5207e9236e3
# 43  Manhattan                Noho  3fd66200f964a5202de51ee3
# 44  Manhattan                Noho  53b8c811498ee296db5cfaed
# 45  Manhattan                Noho  556b8dc2498eb674c015c301
# 46  Manhattan        Civic Center  534c9d7b498e1bdd443a40e1
# 47  Manhattan        Civic Center  3fd66200f964a52083e61ee3
# 48  Manhattan       Midtown South  5b06b57962845c00242fb6be
# 49  Manhattan        Sutton Place  4b70825df964a520e01e2de3
# 50  Manhattan          Turtle Bay  4a64fda8f964a52023c71fe3
#
#                   Name
# 15             Yatenga
# 16  Renaissance Harlem
# 17       Mountain Bird
# 18         Café Boulud
# 19          The Simone
# 20               Orsay
# 21      Jean Claude II
# 22          Bar Boulud
# 23      Chez Josephine
# 24           Marseille
# 25    Gabriel Kreuther
# 26         Saju Bistro
# 27     Le Grainne Cafe
# 28              Loulou
# 29  Raoul's Restaurant
# 30             Cocotte
# 31       Little Prince
# 32        David's Cafe
# 33            Windmill
# 34           Le Coucou
# 35           Balthazar
# 36           Le Coucou
# 37             Buvette
# 38                Bobo
# 39             Tartine
# 40       La Parisienne
# 42        Table d'Hote
# 43              Lucien
# 44        Dirty French
# 45             Wildair
# 46             Racines
# 47           The Odeon
# 48       Maison Kayser
# 49      Bistro Vendome
# 50           Deux Amis

# %%
{
    "tags":[
        "hide-cell",
    ]
}
french_rest_ny[french_rest_ny['Borough']=='Manhattan'].shape
# Out:
# (35, 4)

# %%
{
    "tags":[
        "hide-cell",
    ]
}
french_rest_ny[french_rest_ny['Borough']=='Brooklyn']
# Out:
#      Borough     Neighborhood                        ID  \
# 1   Brooklyn       Greenpoint  5bf358689fca56002c251a87
# 2   Brooklyn       Greenpoint  4bcf1883c564ef3ba33beff0
# 3   Brooklyn  Windsor Terrace  4aee2d5cf964a520b7d221e3
# 4   Brooklyn         Bushwick  55e47d26498e44d12c7c004e
# 5   Brooklyn      Cobble Hill  4f7f8b86e4b088077df30175
# 6   Brooklyn  Carroll Gardens  5df42352f93ca9000762ff64
# 7   Brooklyn  Carroll Gardens  4e2ca88afa76bbf847e6886c
# 8   Brooklyn      Fort Greene  5250553911d262bb0c732ee8
# 9   Brooklyn      Fort Greene  422b9980f964a520d21f1fe3
# 10  Brooklyn         Downtown  5ca3681932b61d0039533330
# 11  Brooklyn      Boerum Hill  41e46880f964a520e11e1fe3
# 12  Brooklyn      Boerum Hill  4d20bc3af7a9a143bcab2f9f
# 13  Brooklyn       North Side  4554c3b0f964a520113d1fe3
# 14  Brooklyn       North Side  49f38062f964a520ae6a1fe3
#
#                          Name
# 1                     Citroën
# 2                    Le Gamin
# 3       Le P'tit Paris Bistro
# 4                   Le Garage
# 5                    Chez Moi
# 6                    Bar Bête
# 7                Jolie Bistro
# 8               Cafe Paulette
# 9                  Maison May
# 10              Pret A Manger
# 11  Bacchus Bistro & Wine Bar
# 12      The Little Sweet Café
# 13                   Juliette
# 14        Pates Et Traditions

# %%
{
    "tags":[
        "hide-cell",
    ]
}
french_rest_ny[french_rest_ny['Borough']=='Brooklyn'].shape
# Out:
# (14, 4)

# %% [markdown]
# ### The distribution per neighborhood is also poor as shows the figure below. Only 4 Neighborhoods, all in Manhattan, have 3 french restaurants.

# %%
{
    "tags":[
        "hide-input",
    ]
}
Num_Neigh = 8 # top 5 for graphing 
french_rest_ny.groupby('Neighborhood')['ID'].count().nlargest(Num_Neigh).plot.bar(figsize=(10,5), color=clr)
plt.title('French Resturants per Neighborhood: NYC', fontsize = 20)
plt.xlabel('Neighborhood', fontsize = 15)
plt.ylabel('French Resturants', fontsize=15)
plt.xticks(rotation = 'horizontal')
plt.show()

# %%
{
    "tags":[
        "remove-cell",
    ]
}

column_names=['Borough', 'Neighborhood', 'ID','Name','Likes','Rating','Tips']
stats_french_rest=pd.DataFrame(columns=column_names)
count=1
for row in french_rest_ny.values.tolist():
    Borough,Neighborhood,ID,Name=row
    try:
        venue_details=get_venue_details(ID)
        print(venue_details)
        id,name,likes,rating,tips=venue_details.values.tolist()[0]
    except IndexError:
        print('No data available for id=',ID)
        id,name,likes,rating,tips=[0]*5 # 0 if does not exist in foursquare
    print('(',count,'/',len(french_rest_ny),')','processed')
    stats_french_rest = stats_french_rest.append({'Borough': Borough,
                                                'Neighborhood': Neighborhood, 
                                                'ID': id,
                                                'Name' : name,
                                                'Likes' : likes,
                                                'Rating' : rating,
                                                'Tips' : tips
                                               }, ignore_index=True)
    count+=1
stats_french_rest.head()
# Out:
# {'meta': {'code': 200, 'requestId': '6031b2381c939b4186f04502'}, 'response': {'venue': {'id': '4d7aa83ee540f04d66ba16dc', 'name': 'Bistro SK', 'contact': {'phone': '7188851670', 'formattedPhone': '(718) 885-1670'}, 'location': {'address': '273 City Island Ave', 'lat': 40.84638676701103, 'lng': -73.78626182722242, 'labeledLatLngs': [{'label': 'display', 'lat': 40.84638676701103, 'lng': -73.78626182722242}, {'label': 'entrance', 'lat': 40.846234, 'lng': -73.786269}], 'postalCode': '10464', 'cc': 'US', 'city': 'Bronx', 'state': 'NY', 'country': 'United States', 'formattedAddress': ['273 City Island Ave', 'Bronx, NY 10464', 'United States']}, 'canonicalUrl': 'https://foursquare.com/v/bistro-sk/4d7aa83ee540f04d66ba16dc', 'categories': [{'id': '4bf58dd8d48988d10c941735', 'name': 'French Restaurant', 'pluralName': 'French Restaurants', 'shortName': 'French', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/french_', 'suffix': '.png'}, 'primary': True}], 'verified': True, 'stats': {'tipCount': 7}, 'url': 'http://bistrosk.com', 'price': {'tier': 3, 'message': 'Expensive', 'currency': '$'}, 'hasMenu': True, 'likes': {'count': 12, 'groups': [{'type': 'others', 'count': 12, 'items': []}], 'summary': '12 Likes'}, 'dislike': False, 'ok': False, 'rating': 7.5, 'ratingColor': 'C5DE35', 'ratingSignals': 20, 'menu': {'type': 'Menu', 'label': 'Menu', 'anchor': 'View Menu', 'url': 'https://foursquare.com/v/bistro-sk/4d7aa83ee540f04d66ba16dc/menu', 'mobileUrl': 'https://foursquare.com/v/4d7aa83ee540f04d66ba16dc/device_menu'}, 'allowMenuUrlEdit': True, 'beenHere': {'count': 0, 'unconfirmedCount': 0, 'marked': False, 'lastCheckinExpiredAt': 0}, 'specials': {'count': 0, 'items': []}, 'photos': {'count': 19, 'groups': [{'type': 'venue', 'name': 'Venue photos', 'count': 19, 'items': [{'id': '57d35e34498ef8be703ec4f8', 'createdAt': 1473470004, 'source': {'name': 'Swarm for iOS', 'url': 'https://www.swarmapp.com'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/81290_9H1Pdp3nUwb5t3BQEWC3F8kg7mKZkJYZRwMi2d8eszo.jpg', 'width': 1440, 'height': 1920, 'visibility': 'public'}]}]}, 'venuePage': {'id': '97766287'}, 'reasons': {'count': 0, 'items': []}, 'page': {'user': {'firstName': 'Bistro SK', 'countryCode': 'US', 'type': 'venuePage', 'venue': {'id': '4d7aa83ee540f04d66ba16dc'}, 'tips': {'count': 0}, 'lists': {'groups': [{'type': 'created', 'count': 2, 'items': []}]}, 'bio': ''}}, 'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}, 'createdAt': 1299884094, 'tips': {'count': 7, 'groups': [{'type': 'others', 'name': 'All tips', 'count': 7, 'items': [{'id': '51f50bb5498e3f4d4728a232', 'createdAt': 1375013813, 'text': 'Great service and food in this cozy City Island bistro. Not your typical City Island "glorified diner" menu. Great find.', 'type': 'user', 'canonicalUrl': 'https://foursquare.com/item/51f50bb5498e3f4d4728a232', 'lang': 'en', 'likes': {'count': 3, 'groups': [{'type': 'others', 'count': 3, 'items': [{'firstName': 'BrooklynBoyO', 'countryCode': 'US'}, {'firstName': 'Ericalee', 'lastName': 'G', 'countryCode': 'US'}, {'firstName': 'Chris', 'lastName': 'R', 'countryCode': 'US'}]}], 'summary': '3 likes'}, 'logView': True, 'agreeCount': 3, 'disagreeCount': 0, 'todo': {'count': 0}, 'user': {'firstName': 'Stephen', 'lastName': 'G', 'countryCode': 'US'}}]}]}, 'shortUrl': 'http://4sq.com/ejMbZ8', 'timeZone': 'America/New_York', 'listed': {'count': 10, 'groups': [{'type': 'others', 'name': 'Lists from other people', 'count': 10, 'items': [{'id': '519af3b0498e6e1b3705d215', 'name': 'wc/hv to try', 'description': '', 'type': 'others', 'user': {'firstName': 'Kobie', 'lastName': 'W', 'countryCode': 'US'}, 'editable': False, 'public': True, 'collaborative': False, 'url': '/user/56807089/list/wchv-to-try', 'canonicalUrl': 'https://foursquare.com/user/56807089/list/wchv-to-try', 'createdAt': 1369109424, 'updatedAt': 1613541864, 'followers': {'count': 2}, 'listItems': {'count': 289, 'items': [{'id': 'v4d7aa83ee540f04d66ba16dc', ...
#                          ID       Name  Likes  Rating  Tips
# 0  4d7aa83ee540f04d66ba16dc  Bistro SK     12     7.5     7
# ( 1 / 53 ) processed
# {'meta': {'code': 200, 'requestId': '6031b2383e9575501b851c74'}, 'response': {'venue': {'id': '5bf358689fca56002c251a87', 'name': 'Citroën', 'contact': {}, 'location': {'address': '931 Manhattan Ave', 'lat': 40.731173193581775, 'lng': -73.95452252962613, 'labeledLatLngs': [{'label': 'display', 'lat': 40.731173193581775, 'lng': -73.95452252962613}], 'postalCode': '11222', 'cc': 'US', 'city': 'New York', 'state': 'NY', 'country': 'United States', 'formattedAddress': ['931 Manhattan Ave', 'New York, NY 11222', 'United States']}, 'canonicalUrl': 'https://foursquare.com/v/citro%C3%ABn/5bf358689fca56002c251a87', 'categories': [{'id': '4bf58dd8d48988d10c941735', 'name': 'French Restaurant', 'pluralName': 'French Restaurants', 'shortName': 'French', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/french_', 'suffix': '.png'}, 'primary': True}], 'verified': False, 'stats': {'tipCount': 3}, 'price': {'tier': 3, 'message': 'Expensive', 'currency': '$'}, 'likes': {'count': 23, 'groups': [{'type': 'others', 'count': 23, 'items': []}], 'summary': '23 Likes'}, 'dislike': False, 'ok': False, 'rating': 8.6, 'ratingColor': '73CF42', 'ratingSignals': 28, 'delivery': {'id': '1448912', 'url': 'https://www.seamless.com/menu/citroen-931-manhattan-ave-brooklyn/1448912?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1448912', 'provider': {'name': 'seamless', 'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/', 'sizes': [40, 50], 'name': '/delivery_provider_seamless_20180129.png'}}}, 'allowMenuUrlEdit': True, 'beenHere': {'count': 0, 'unconfirmedCount': 0, 'marked': False, 'lastCheckinExpiredAt': 0}, 'specials': {'count': 0, 'items': []}, 'photos': {'count': 6, 'groups': [{'type': 'venue', 'name': 'Venue photos', 'count': 6, 'items': [{'id': '5dd9cb47bc9461000892e17e', 'createdAt': 1574554439, 'source': {'name': 'Swarm for iOS', 'url': 'https://www.swarmapp.com'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/43981620_9TYCj2FGcES1UgHMvL1YDmu_9-sGuzxZHfRHGdXwZEs.jpg', 'width': 1920, 'height': 1440, 'visibility': 'public'}]}]}, 'reasons': {'count': 0, 'items': []}, 'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}, 'createdAt': 1542674536, 'tips': {'count': 3, 'groups': [{'type': 'others', 'name': 'All tips', 'count': 3, 'items': [{'id': '5cb67b0efe3740002c4df4fb', 'createdAt': 1555462926, 'text': 'Is it French? I had the avocado toast which was delicious and healthy. Will come back for brunch.', 'type': 'user', 'canonicalUrl': 'https://foursquare.com/item/5cb67b0efe3740002c4df4fb', 'lang': 'en', 'likes': {'count': 0, 'groups': []}, 'logView': True, 'agreeCount': 1, 'disagreeCount': 0, 'todo': {'count': 0}, 'user': {'firstName': 'Silene', 'lastName': 'L', 'countryCode': 'US'}, 'authorInteractionType': 'liked'}]}]}, 'shortUrl': 'https://4sq.com/2PHbzyU', 'timeZone': 'America/New_York', 'listed': {'count': 41, 'groups': [{'type': 'others', 'name': 'Lists from other people', 'count': 41, 'items': [{'id': '588effbff840850a81fa87a0', 'name': 'NYC × Eat × Drink', 'description': '', 'type': 'others', 'user': {'firstName': 'Pat', 'lastName': 'C', 'countryCode': 'DE'}, 'editable': False, 'public': True, 'collaborative': False, 'url': '/plstcpssn/list/nyc--eat--drink', 'canonicalUrl': 'https://foursquare.com/plstcpssn/list/nyc--eat--drink', 'createdAt': 1485766591, 'updatedAt': 1547070454, 'followers': {'count': 1}, 'listItems': {'count': 102, 'items': [{'id': 'v5bf358689fca56002c251a87', 'createdAt': 1545427936}]}}, {'id': '531f2e3c498e0bd1e4e8bb38', 'name': 'Brooklyn restaurants', 'description': '', 'type': 'others', 'user': {'firstName': 'Jessica', 'lastName': 'F', 'countryCode': 'US'}, 'editable': False, 'public': True, 'collaborative': False, 'url': '/user/77565384/list/brooklyn-restaurants', 'canonicalUrl': 'https://foursquare.com/user/77565384/list/brooklyn-restaurants', 'createdAt': 1394552380, 'updatedAt': 1612480151, 'followers': {'count': 1}, ...
#                          ID     Name  Likes  Rating  Tips
# 0  5bf358689fca56002c251a87  Citroën     23     8.6     3
# ( 2 / 53 ) processed
# {'meta': {'code': 200, 'requestId': '6031b239f3736534d0d4a55e'}, 'response': {'venue': {'id': '4bcf1883c564ef3ba33beff0', 'name': 'Le Gamin', 'contact': {'phone': '7187707918', 'formattedPhone': '(718) 770-7918', 'twitter': 'legamin'}, 'location': {'address': '108 Franklin St', 'crossStreet': 'at Noble St.', 'lat': 40.72828009841782, 'lng': -73.95733511406732, 'labeledLatLngs': [{'label': 'display', 'lat': 40.72828009841782, 'lng': -73.95733511406732}, {'label': 'entrance', 'lat': 40.728287, 'lng': -73.957206}], 'postalCode': '11222', 'cc': 'US', 'city': 'Brooklyn', 'state': 'NY', 'country': 'United States', 'formattedAddress': ['108 Franklin St (at Noble St.)', 'Brooklyn, NY 11222', 'United States']}, 'canonicalUrl': 'https://foursquare.com/v/le-gamin/4bcf1883c564ef3ba33beff0', 'categories': [{'id': '4bf58dd8d48988d10c941735', 'name': 'French Restaurant', 'pluralName': 'French Restaurants', 'shortName': 'French', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/french_', 'suffix': '.png'}, 'primary': True}, {'id': '4bf58dd8d48988d16d941735', 'name': 'Café', 'pluralName': 'Cafés', 'shortName': 'Café', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_', 'suffix': '.png'}}], 'verified': False, 'stats': {'tipCount': 73}, 'url': 'http://www.legamin.com', 'price': {'tier': 2, 'message': 'Moderate', 'currency': '$'}, 'hasMenu': True, 'likes': {'count': 159, 'groups': [{'type': 'others', 'count': 159, 'items': []}], 'summary': '159 Likes'}, 'dislike': False, 'ok': False, 'rating': 7.6, 'ratingColor': 'C5DE35', 'ratingSignals': 253, 'delivery': {'id': '295021', 'url': 'https://www.seamless.com/menu/le-gamin-108-franklin-st-brooklyn/295021?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=295021', 'provider': {'name': 'seamless', 'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/', 'sizes': [40, 50], 'name': '/delivery_provider_seamless_20180129.png'}}}, 'menu': {'type': 'Menu', 'label': 'Menu', 'anchor': 'View Menu', 'url': 'https://foursquare.com/v/le-gamin/4bcf1883c564ef3ba33beff0/menu', 'mobileUrl': 'https://foursquare.com/v/4bcf1883c564ef3ba33beff0/device_menu'}, 'allowMenuUrlEdit': True, 'beenHere': {'count': 0, 'unconfirmedCount': 0, 'marked': False, 'lastCheckinExpiredAt': 0}, 'specials': {'count': 0, 'items': []}, 'photos': {'count': 162, 'groups': [{'type': 'venue', 'name': 'Venue photos', 'count': 162, 'items': [{'id': '51a63dbc498ed3538be2bfda', 'createdAt': 1369849276, 'source': {'name': 'Foursquare for iOS', 'url': 'https://foursquare.com/download/#/iphone'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/3362535_4u7FHj-7hjxIeHRKLy8JSVfCeOITDKtqRqfNblhR7AM.jpg', 'width': 1440, 'height': 1920, 'visibility': 'public'}]}]}, 'reasons': {'count': 1, 'items': [{'summary': 'Lots of people like this place', 'type': 'general', 'reasonName': 'rawLikesReason'}]}, 'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}, 'createdAt': 1271863427, 'tips': {'count': 73, 'groups': [{'type': 'others', 'name': 'All tips', 'count': 73, 'items': [{'id': '5068e7cfe4b07b0b78f867b3', 'createdAt': 1349052367, 'text': 'Here for brunch? Order the Croque Madame - a grilled ham and cheese with an egg on it', 'type': 'user', 'canonicalUrl': 'https://foursquare.com/item/5068e7cfe4b07b0b78f867b3', 'photo': {'id': '5068e7d0e4b052937957e1a2', 'createdAt': 1349052368, 'source': {'name': 'Foursquare for iOS', 'url': 'https://foursquare.com/download/#/iphone'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/29125_htCoFN5UXw9N9xLy8i-grWKiHhYoBdTxQgFfoSVUNQM.jpg', 'width': 540, 'height': 540, 'visibility': 'public'}, 'photourl': 'https://fastly.4sqi.net/img/general/original/29125_htCoFN5UXw9N9xLy8i-grWKiHhYoBdTxQgFfoSVUNQM.jpg', 'lang': 'en', 'likes': {'count': 2, 'groups': [{'type': 'others', 'count': 2, 'items': [{'firstName': 'ᴡ', 'lastName': 'F', 'address': '', 'city': '', 'state': '', 'countryCode': 'US'}, {'firstName' ...
#                          ID      Name  Likes  Rating  Tips
# 0  4bcf1883c564ef3ba33beff0  Le Gamin    159     7.6    73
# ( 3 / 53 ) processed
# {'meta': {'code': 200, 'requestId': '6031b239d8ba7776dfd88f76'}, 'response': {'venue': {'id': '4aee2d5cf964a520b7d221e3', 'name': "Le P'tit Paris Bistro", 'contact': {'phone': '7183693590', 'formattedPhone': '(718) 369-3590'}, 'location': {'address': '256 Prospect Park W', 'crossStreet': 'Prospect Ave', 'lat': 40.65890343822447, 'lng': -73.98175905027033, 'labeledLatLngs': [{'label': 'display', 'lat': 40.65890343822447, 'lng': -73.98175905027033}, {'label': 'entrance', 'lat': 40.658984, 'lng': -73.981722}], 'postalCode': '11215', 'cc': 'US', 'city': 'Brooklyn', 'state': 'NY', 'country': 'United States', 'formattedAddress': ['256 Prospect Park W (Prospect Ave)', 'Brooklyn, NY 11215', 'United States']}, 'canonicalUrl': 'https://foursquare.com/v/le-ptit-paris-bistro/4aee2d5cf964a520b7d221e3', 'categories': [{'id': '4bf58dd8d48988d10c941735', 'name': 'French Restaurant', 'pluralName': 'French Restaurants', 'shortName': 'French', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/french_', 'suffix': '.png'}, 'primary': True}], 'verified': True, 'stats': {'tipCount': 32}, 'url': 'http://www.leptitparisbistro.com', 'price': {'tier': 2, 'message': 'Moderate', 'currency': '$'}, 'hasMenu': True, 'likes': {'count': 55, 'groups': [{'type': 'others', 'count': 55, 'items': []}], 'summary': '55 Likes'}, 'dislike': False, 'ok': False, 'rating': 7.5, 'ratingColor': 'C5DE35', 'ratingSignals': 98, 'menu': {'type': 'Menu', 'label': 'Menu', 'anchor': 'View Menu', 'url': 'https://foursquare.com/v/le-ptit-paris-bistro/4aee2d5cf964a520b7d221e3/menu', 'mobileUrl': 'https://foursquare.com/v/4aee2d5cf964a520b7d221e3/device_menu'}, 'allowMenuUrlEdit': True, 'beenHere': {'count': 0, 'unconfirmedCount': 0, 'marked': False, 'lastCheckinExpiredAt': 0}, 'specials': {'count': 0, 'items': []}, 'photos': {'count': 73, 'groups': [{'type': 'venue', 'name': 'Venue photos', 'count': 73, 'items': [{'id': '4ddc05b7a12d876ae51d7ca5', 'createdAt': 1306265015, 'source': {'name': 'Foursquare for iOS', 'url': 'https://foursquare.com/download/#/iphone'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/0GBBALANOXV5WCUEZUOGYVAJI34BS1U4Y00CMEUQ1MWYQDYP.jpg', 'width': 537, 'height': 720, 'visibility': 'public'}]}]}, 'venuePage': {'id': '81197754'}, 'reasons': {'count': 1, 'items': [{'summary': 'Lots of people like this place', 'type': 'general', 'reasonName': 'rawLikesReason'}]}, 'page': {'user': {'firstName': "Le P'tit Paris Bistro", 'countryCode': 'US', 'type': 'venuePage', 'venue': {'id': '4aee2d5cf964a520b7d221e3'}, 'tips': {'count': 0}, 'lists': {'groups': [{'type': 'created', 'count': 2, 'items': []}]}, 'bio': ''}}, 'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}, 'createdAt': 1257123164, 'tips': {'count': 32, 'groups': [{'type': 'others', 'name': 'All tips', 'count': 32, 'items': [{'id': '5199015f498e2a7929b0aa17', 'createdAt': 1368981855, 'text': 'Amazing deal for brunch. $16 for an entree and unlimited mimosas, house wine, sangria, or bloody marys.', 'type': 'user', 'canonicalUrl': 'https://foursquare.com/item/5199015f498e2a7929b0aa17', 'lang': 'en', 'likes': {'count': 3, 'groups': [{'type': 'others', 'count': 3, 'items': [{'firstName': 'Kit Kat🍫', 'countryCode': 'US'}, {'firstName': 'Julien', 'lastName': 'L', 'countryCode': 'US'}]}], 'summary': '3 likes'}, 'logView': True, 'agreeCount': 2, 'disagreeCount': 0, 'todo': {'count': 1}, 'user': {'firstName': 'James', 'lastName': 'S', 'countryCode': 'US'}}]}]}, 'shortUrl': 'http://4sq.com/4ZSl1z', 'timeZone': 'America/New_York', 'listed': {'count': 61, 'groups': [{'type': 'others', 'name': 'Lists from other people', 'count': 61, 'items': [{'id': '4e628876b993678bb67fa75d', 'name': 'Outdoor Drinks in Lower BK', 'description': 'places with outdoor sidewalk or garden seating, and hopefully pitchers!', 'type': 'others', 'user': {'firstName': 'phaedra', 'lastName': 'r', 'countryCode': 'US'}, 'editable': False, 'public': True, 'collaborative': True, 'url': '/buhny/list/outdoor-drinks-in-l ...
#                          ID                   Name  Likes  Rating  Tips
# 0  4aee2d5cf964a520b7d221e3  Le P'tit Paris Bistro     55     7.5    32
# ( 4 / 53 ) processed
# {'meta': {'code': 200, 'requestId': '6031b239c769a12f9a3c6d14'}, 'response': {'venue': {'id': '55e47d26498e44d12c7c004e', 'name': 'Le Garage', 'contact': {'phone': '3472951700', 'formattedPhone': '(347) 295-1700', 'facebook': '1428692160759373', 'facebookUsername': 'legaragebk', 'facebookName': 'Le Garage'}, 'location': {'address': '157 Suydam st', 'crossStreet': 'Central ave', 'lat': 40.69931158121694, 'lng': -73.92659110766274, 'labeledLatLngs': [{'label': 'display', 'lat': 40.69931158121694, 'lng': -73.92659110766274}], 'postalCode': '11221', 'cc': 'US', 'city': 'Brooklyn', 'state': 'NY', 'country': 'United States', 'formattedAddress': ['157 Suydam st (Central ave)', 'Brooklyn, NY 11221', 'United States']}, 'canonicalUrl': 'https://foursquare.com/v/le-garage/55e47d26498e44d12c7c004e', 'categories': [{'id': '4bf58dd8d48988d10c941735', 'name': 'French Restaurant', 'pluralName': 'French Restaurants', 'shortName': 'French', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/french_', 'suffix': '.png'}, 'primary': True}], 'verified': True, 'stats': {'tipCount': 25}, 'url': 'http://www.legaragebrooklyn.com', 'price': {'tier': 3, 'message': 'Expensive', 'currency': '$'}, 'likes': {'count': 99, 'groups': [{'type': 'others', 'count': 99, 'items': []}], 'summary': '99 Likes'}, 'dislike': False, 'ok': False, 'rating': 7.9, 'ratingColor': 'C5DE35', 'ratingSignals': 132, 'delivery': {'id': '2488154', 'url': 'https://www.seamless.com/menu/le-garage-157-suydam-st-brooklyn/2488154?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2488154', 'provider': {'name': 'seamless', 'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/', 'sizes': [40, 50], 'name': '/delivery_provider_seamless_20180129.png'}}}, 'menu': {'type': 'Menu', 'label': 'Menu', 'anchor': 'View Menu', 'url': 'http://legaragebrooklyn.com/menu/', 'mobileUrl': 'http://legaragebrooklyn.com/menu/', 'externalUrl': 'http://legaragebrooklyn.com/menu/'}, 'allowMenuUrlEdit': True, 'beenHere': {'count': 0, 'unconfirmedCount': 0, 'marked': False, 'lastCheckinExpiredAt': 0}, 'specials': {'count': 0, 'items': []}, 'photos': {'count': 33, 'groups': [{'type': 'venue', 'name': 'Venue photos', 'count': 33, 'items': [{'id': '56c5ebf5498ee801e31a910f', 'createdAt': 1455811573, 'source': {'name': 'Foursquare Web', 'url': 'https://foursquare.com'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/158936150_1pxzc1aCETk1m-rcx3EZwFTQImXM31AJt_cSV9EVT8Q.jpg', 'width': 4288, 'height': 2848, 'visibility': 'public'}]}]}, 'venuePage': {'id': '158936150'}, 'reasons': {'count': 1, 'items': [{'summary': 'Lots of people like this place', 'type': 'general', 'reasonName': 'rawLikesReason'}]}, 'description': 'French with a twist! From Paris to Brooklyn, Mother & daughter come together to offer seasonal family recipes with spices from the world.', 'storeId': '', 'page': {'user': {'firstName': 'Le Garage', 'countryCode': 'US', 'type': 'venuePage', 'venue': {'id': '55e47d26498e44d12c7c004e'}, 'tips': {'count': 0}, 'lists': {'groups': [{'type': 'created', 'count': 2, 'items': []}]}, 'bio': ''}}, 'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}, 'createdAt': 1441037606, 'tips': {'count': 25, 'groups': [{'type': 'others', 'name': 'All tips', 'count': 25, 'items': [{'id': '56c722f8498ebbd60f021fb0', 'createdAt': 1455891192, 'text': 'Solid, unpretentious French food. Try the smoked haddock rillette.', 'type': 'user', 'canonicalUrl': 'https://foursquare.com/item/56c722f8498ebbd60f021fb0', 'lang': 'en', 'likes': {'count': 3, 'groups': [{'type': 'others', 'count': 3, 'items': [{'firstName': 'Mike', 'lastName': 'W', 'countryCode': 'US'}, {'firstName': 'Rachel', 'lastName': 'A', 'countryCode': 'US'}]}], 'summary': '3 likes'}, 'logView': True, 'agreeCount': 3, 'disagreeCount': 0, 'todo': {'count': 0}, 'user': {'firstName': 'Ryan', 'lastName': 'M', 'countryCode': 'US'}, 'authorInteractionType': 'liked'}]}]}, 'shortUrl': 'http: ...
#                          ID       Name  Likes  Rating  Tips
# 0  55e47d26498e44d12c7c004e  Le Garage     99     7.9    25
# ( 5 / 53 ) processed
# {'meta': {'code': 200, 'requestId': '6031b23933ec8c2cb0b0fe1e'}, 'response': {'venue': {'id': '4f7f8b86e4b088077df30175', 'name': 'Chez Moi', 'contact': {'phone': '3472278337', 'formattedPhone': '(347) 227-8337', 'facebook': '106096576191722', 'facebookUsername': 'chezmoiny', 'facebookName': 'Chez Moi'}, 'location': {'address': '135 Atlantic Ave', 'crossStreet': 'at Henry St', 'lat': 40.690654299028225, 'lng': -73.99577681819873, 'labeledLatLngs': [{'label': 'display', 'lat': 40.690654299028225, 'lng': -73.99577681819873}], 'postalCode': '11201', 'cc': 'US', 'city': 'Brooklyn', 'state': 'NY', 'country': 'United States', 'formattedAddress': ['135 Atlantic Ave (at Henry St)', 'Brooklyn, NY 11201', 'United States']}, 'canonicalUrl': 'https://foursquare.com/v/chez-moi/4f7f8b86e4b088077df30175', 'categories': [{'id': '4bf58dd8d48988d10c941735', 'name': 'French Restaurant', 'pluralName': 'French Restaurants', 'shortName': 'French', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/french_', 'suffix': '.png'}, 'primary': True}, {'id': '4bf58dd8d48988d11e941735', 'name': 'Cocktail Bar', 'pluralName': 'Cocktail Bars', 'shortName': 'Cocktail', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/cocktails_', 'suffix': '.png'}}], 'verified': True, 'stats': {'tipCount': 75}, 'url': 'http://chezmoiny.com', 'price': {'tier': 2, 'message': 'Moderate', 'currency': '$'}, 'likes': {'count': 203, 'groups': [{'type': 'others', 'count': 203, 'items': []}], 'summary': '203 Likes'}, 'dislike': False, 'ok': False, 'rating': 8.4, 'ratingColor': '73CF42', 'ratingSignals': 291, 'delivery': {'id': '2120138', 'url': 'https://www.seamless.com/menu/chez-moi-135-atlantic-ave-brooklyn/2120138?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2120138', 'provider': {'name': 'seamless', 'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/', 'sizes': [40, 50], 'name': '/delivery_provider_seamless_20180129.png'}}}, 'allowMenuUrlEdit': True, 'beenHere': {'count': 0, 'unconfirmedCount': 0, 'marked': False, 'lastCheckinExpiredAt': 0}, 'specials': {'count': 0, 'items': []}, 'photos': {'count': 147, 'groups': [{'type': 'venue', 'name': 'Venue photos', 'count': 147, 'items': [{'id': '4fe102cce4b050b31dc66c78', 'createdAt': 1340146380, 'source': {'name': 'Foursquare for iOS', 'url': 'https://foursquare.com/download/#/iphone'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/LKvk1ndZnTu3c0C3_5BKQDkxSKtEaqWP-3A_2nT_7JQ.jpg', 'width': 540, 'height': 540, 'visibility': 'public'}]}]}, 'venuePage': {'id': '60373896'}, 'reasons': {'count': 1, 'items': [{'summary': 'Lots of people like this place', 'type': 'general', 'reasonName': 'rawLikesReason'}]}, 'description': 'French bistro, Cocktail bar, Restaurant, Brunch, Lunch & Dinner', 'storeId': '', 'page': {'user': {'firstName': 'Chez Moi', 'countryCode': 'US', 'type': 'venuePage', 'venue': {'id': '4f7f8b86e4b088077df30175'}, 'tips': {'count': 0}, 'lists': {'groups': [{'type': 'created', 'count': 2, 'items': []}]}, 'bio': ''}}, 'hereNow': {'count': 1, 'summary': 'One other person is here', 'groups': [{'type': 'others', 'name': 'Other people here', 'count': 1, 'items': []}]}, 'createdAt': 1333758854, 'tips': {'count': 75, 'groups': [{'type': 'others', 'name': 'All tips', 'count': 75, 'items': [{'id': '50e25100e4b05f45abdae83b', 'createdAt': 1357009152, 'text': 'try the kombucha martini. made with cucumber vodka, raspberries, kombucha and chia seeds! the healthiest martini your lips will ever touch.', 'type': 'user', 'canonicalUrl': 'https://foursquare.com/item/50e25100e4b05f45abdae83b', 'lang': 'en', 'likes': {'count': 5, 'groups': [{'type': 'others', 'count': 5, 'items': [{'firstName': 'Christina Renee', 'lastName': 'J', 'countryCode': 'SE'}, {'firstName': 'Courtney', 'lastName': 'B', 'countryCode': 'US'}, {'firstName': 'Mike', 'lastName': 'K', 'countryCode': 'US'}, {'firstName': 'Chez Moi', 'countryCode': 'US', 'type': 'ven ...
#                          ID      Name  Likes  Rating  Tips
# 0  4f7f8b86e4b088077df30175  Chez Moi    203     8.4    75
# ( 6 / 53 ) processed
# {'meta': {'code': 200, 'requestId': '6031b2393916cb7a77376f20'}, 'response': {'venue': {'id': '5df42352f93ca9000762ff64', 'name': 'Bar Bête', 'contact': {'phone': '3478449950', 'formattedPhone': '(347) 844-9950'}, 'location': {'address': '263 Smith St', 'crossStreet': 'at Degraw St', 'lat': 40.682922, 'lng': -73.992907, 'labeledLatLngs': [{'label': 'display', 'lat': 40.682922, 'lng': -73.992907}], 'postalCode': '11231', 'cc': 'US', 'city': 'New York', 'state': 'NY', 'country': 'United States', 'formattedAddress': ['263 Smith St (at Degraw St)', 'New York, NY 11231', 'United States']}, 'canonicalUrl': 'https://foursquare.com/v/bar-b%C3%AAte/5df42352f93ca9000762ff64', 'categories': [{'id': '4bf58dd8d48988d10c941735', 'name': 'French Restaurant', 'pluralName': 'French Restaurants', 'shortName': 'French', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/french_', 'suffix': '.png'}, 'primary': True}, {'id': '4bf58dd8d48988d11d941735', 'name': 'Sports Bar', 'pluralName': 'Sports Bars', 'shortName': 'Sports Bar', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/sportsbar_', 'suffix': '.png'}}, {'id': '4bf58dd8d48988d110941735', 'name': 'Italian Restaurant', 'pluralName': 'Italian Restaurants', 'shortName': 'Italian', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_', 'suffix': '.png'}}], 'verified': False, 'stats': {'tipCount': 4}, 'url': 'https://www.barbete.com', 'price': {'tier': 3, 'message': 'Expensive', 'currency': '$'}, 'likes': {'count': 22, 'groups': [{'type': 'others', 'count': 22, 'items': []}], 'summary': '22 Likes'}, 'dislike': False, 'ok': False, 'rating': 8.4, 'ratingColor': '73CF42', 'ratingSignals': 26, 'allowMenuUrlEdit': True, 'beenHere': {'count': 0, 'unconfirmedCount': 0, 'marked': False, 'lastCheckinExpiredAt': 0}, 'specials': {'count': 0, 'items': []}, 'photos': {'count': 3, 'groups': [{'type': 'venue', 'name': 'Venue photos', 'count': 3, 'items': [{'id': '5e337f7430cb8c0008c68713', 'createdAt': 1580433268, 'source': {'name': 'Swarm for Android', 'url': 'https://www.swarmapp.com'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/83467837_FH3tEAOnJ0TBOds27Of0gwHrlnbeWLfDQCj3aRaNUHo.jpg', 'width': 1080, 'height': 1440, 'visibility': 'public'}]}]}, 'reasons': {'count': 0, 'items': []}, 'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}, 'createdAt': 1576280914, 'tips': {'count': 4, 'groups': [{'type': 'others', 'name': 'All tips', 'count': 4, 'items': [{'id': '5f387bf3b048ed259f2842f6', 'createdAt': 1597537267, 'text': 'duck. fat. potatoes.', 'type': 'user', 'canonicalUrl': 'https://foursquare.com/item/5f387bf3b048ed259f2842f6', 'lang': 'en', 'likes': {'count': 0, 'groups': []}, 'logView': True, 'agreeCount': 1, 'disagreeCount': 0, 'todo': {'count': 0}, 'user': {'firstName': 'Charles', 'lastName': 'B', 'countryCode': 'US'}, 'authorInteractionType': 'liked'}]}]}, 'shortUrl': 'https://4sq.com/2M3xz3c', 'timeZone': 'America/New_York', 'listed': {'count': 97, 'groups': [{'type': 'others', 'name': 'Lists from other people', 'count': 97, 'items': [{'id': '5c028cd6fc9e94002c0312dd', 'name': 'Brooklyn Food & Drink', 'description': '', 'type': 'others', 'user': {'firstName': 'Eva', 'lastName': 'G', 'countryCode': 'US'}, 'editable': False, 'public': True, 'collaborative': False, 'url': '/user/142243619/list/brooklyn-food--drink', 'canonicalUrl': 'https://foursquare.com/user/142243619/list/brooklyn-food--drink', 'createdAt': 1543670998, 'updatedAt': 1592256022, 'followers': {'count': 6}, 'listItems': {'count': 175, 'items': [{'id': 'v5df42352f93ca9000762ff64', 'createdAt': 1582985595}]}}, {'id': '4f57a5e3e4b08a52ee0b427d', 'name': 'Bk/Q food', 'description': '', 'type': 'others', 'user': {'firstName': 'Mike', 'lastName': 'H', 'countryCode': 'US'}, 'editable': False, 'public': True, 'collaborative': False, 'url': '/user/18432046/list/bkq-food', 'canonicalUrl': 'https://foursquare.com/user/18432046/list/bkq-food', 'createdAt': 1331144163, 'up ...
#                          ID      Name  Likes  Rating  Tips
# 0  5df42352f93ca9000762ff64  Bar Bête     22     8.4     4
# ( 7 / 53 ) processed
# {'meta': {'code': 200, 'requestId': '6031b239e4b7b103a551b464'}, 'response': {'venue': {'id': '4e2ca88afa76bbf847e6886c', 'name': 'Jolie Bistro', 'contact': {'phone': '7184180777', 'formattedPhone': '(718) 418-0777', 'twitter': 'joliecantina'}, 'location': {'address': '241 Smith St', 'crossStreet': 'at Douglass St', 'lat': 40.683534960802, 'lng': -73.99254139304226, 'labeledLatLngs': [{'label': 'display', 'lat': 40.683534960802, 'lng': -73.99254139304226}, {'label': 'entrance', 'lat': 40.683605, 'lng': -73.992463}], 'postalCode': '11231', 'cc': 'US', 'city': 'Brooklyn', 'state': 'NY', 'country': 'United States', 'formattedAddress': ['241 Smith St (at Douglass St)', 'Brooklyn, NY 11231', 'United States']}, 'canonicalUrl': 'https://foursquare.com/v/jolie-bistro/4e2ca88afa76bbf847e6886c', 'categories': [{'id': '4bf58dd8d48988d10c941735', 'name': 'French Restaurant', 'pluralName': 'French Restaurants', 'shortName': 'French', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/french_', 'suffix': '.png'}, 'primary': True}, {'id': '4bf58dd8d48988d1c1941735', 'name': 'Mexican Restaurant', 'pluralName': 'Mexican Restaurants', 'shortName': 'Mexican', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/mexican_', 'suffix': '.png'}}], 'verified': True, 'stats': {'tipCount': 78}, 'url': 'http://joliecantina.com', 'price': {'tier': 3, 'message': 'Expensive', 'currency': '$'}, 'hasMenu': True, 'likes': {'count': 213, 'groups': [{'type': 'others', 'count': 213, 'items': []}], 'summary': '213 Likes'}, 'dislike': False, 'ok': False, 'rating': 7.5, 'ratingColor': 'C5DE35', 'ratingSignals': 314, 'menu': {'type': 'Menu', 'label': 'Menu', 'anchor': 'View Menu', 'url': 'https://foursquare.com/v/jolie-bistro/4e2ca88afa76bbf847e6886c/menu', 'mobileUrl': 'https://foursquare.com/v/4e2ca88afa76bbf847e6886c/device_menu'}, 'allowMenuUrlEdit': True, 'beenHere': {'count': 0, 'unconfirmedCount': 0, 'marked': False, 'lastCheckinExpiredAt': 0}, 'specials': {'count': 0, 'items': []}, 'photos': {'count': 241, 'groups': [{'type': 'venue', 'name': 'Venue photos', 'count': 241, 'items': [{'id': '5064ddfae4b0468ca729b2af', 'createdAt': 1348787706, 'source': {'name': 'Instagram', 'url': 'http://instagram.com'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/1309162_-mLiRsisbgY9bKSkDj1ac_71XwRnXfzDEke4CvXB-34.jpg', 'width': 612, 'height': 612, 'visibility': 'public'}]}]}, 'venuePage': {'id': '83854496'}, 'reasons': {'count': 1, 'items': [{'summary': 'Lots of people like this place', 'type': 'general', 'reasonName': 'rawLikesReason'}]}, 'page': {'user': {'firstName': 'Jolie Bistro', 'countryCode': 'US', 'type': 'venuePage', 'venue': {'id': '4e2ca88afa76bbf847e6886c'}, 'tips': {'count': 0}, 'lists': {'groups': [{'type': 'created', 'count': 2, 'items': []}]}, 'bio': ''}}, 'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}, 'createdAt': 1311549578, 'tips': {'count': 78, 'groups': [{'type': 'others', 'name': 'All tips', 'count': 78, 'items': [{'id': '5370d2ef11d2228b33e70a86', 'createdAt': 1399902959, 'text': "Great place for a a mexican/french themed weekend brunch. It's also very kid friendly and the service is fast and efficient. Get the fish tacos or if you're a meat lover, the JC is great.", 'type': 'user', 'canonicalUrl': 'https://foursquare.com/item/5370d2ef11d2228b33e70a86', 'lang': 'en', 'likes': {'count': 4, 'groups': [{'type': 'others', 'count': 4, 'items': [{'firstName': 'Fernando', 'lastName': 'M', 'countryCode': 'US'}, {'firstName': 'Ric', 'lastName': 'C', 'countryCode': 'US'}, {'firstName': 'Dennis', 'lastName': 'B', 'countryCode': 'US'}]}], 'summary': '4 likes'}, 'logView': True, 'agreeCount': 6, 'disagreeCount': 0, 'todo': {'count': 0}, 'user': {'firstName': 'Oz', 'lastName': 'L', 'countryCode': 'US'}, 'authorInteractionType': 'liked'}]}]}, 'shortUrl': 'http://4sq.com/nH7a40', 'timeZone': 'America/New_York', 'listed': {'count': 140, 'groups': [{'type': 'others', 'name': 'Lists from other people', 'count': ...
#                          ID          Name  Likes  Rating  Tips
# 0  4e2ca88afa76bbf847e6886c  Jolie Bistro    213     7.5    78
# ( 8 / 53 ) processed
# {'meta': {'code': 200, 'requestId': '6031b23a22b38d24d0ad5167'}, 'response': {'venue': {'id': '5250553911d262bb0c732ee8', 'name': 'Cafe Paulette', 'contact': {'phone': '7188528582', 'formattedPhone': '(718) 852-8582'}, 'location': {'address': '1 S Elliott Pl', 'lat': 40.68974307741666, 'lng': -73.97579775071402, 'labeledLatLngs': [{'label': 'display', 'lat': 40.68974307741666, 'lng': -73.97579775071402}], 'postalCode': '11217', 'cc': 'US', 'city': 'Brooklyn', 'state': 'NY', 'country': 'United States', 'formattedAddress': ['1 S Elliott Pl', 'Brooklyn, NY 11217', 'United States']}, 'canonicalUrl': 'https://foursquare.com/v/cafe-paulette/5250553911d262bb0c732ee8', 'categories': [{'id': '4bf58dd8d48988d10c941735', 'name': 'French Restaurant', 'pluralName': 'French Restaurants', 'shortName': 'French', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/french_', 'suffix': '.png'}, 'primary': True}, {'id': '4bf58dd8d48988d16d941735', 'name': 'Café', 'pluralName': 'Cafés', 'shortName': 'Café', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_', 'suffix': '.png'}}, {'id': '4bf58dd8d48988d123941735', 'name': 'Wine Bar', 'pluralName': 'Wine Bars', 'shortName': 'Wine Bar', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/winery_', 'suffix': '.png'}}], 'verified': True, 'stats': {'tipCount': 53}, 'url': 'http://cafepaulette.com', 'price': {'tier': 2, 'message': 'Moderate', 'currency': '$'}, 'hasMenu': True, 'likes': {'count': 216, 'groups': [{'type': 'others', 'count': 216, 'items': []}], 'summary': '216 Likes'}, 'dislike': False, 'ok': False, 'rating': 8.6, 'ratingColor': '73CF42', 'ratingSignals': 296, 'delivery': {'id': '2035776', 'url': 'https://www.seamless.com/menu/cafe-paulette-1-s-elliott-pl-brooklyn/2035776?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2035776', 'provider': {'name': 'seamless', 'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/', 'sizes': [40, 50], 'name': '/delivery_provider_seamless_20180129.png'}}}, 'menu': {'type': 'Menu', 'label': 'Menu', 'anchor': 'View Menu', 'url': 'https://foursquare.com/v/cafe-paulette/5250553911d262bb0c732ee8/menu', 'mobileUrl': 'https://foursquare.com/v/5250553911d262bb0c732ee8/device_menu', 'externalUrl': 'http://cafepaulette.com/menus/'}, 'allowMenuUrlEdit': True, 'beenHere': {'count': 0, 'unconfirmedCount': 0, 'marked': False, 'lastCheckinExpiredAt': 0}, 'specials': {'count': 0, 'items': []}, 'photos': {'count': 73, 'groups': [{'type': 'venue', 'name': 'Venue photos', 'count': 73, 'items': [{'id': '52dd66c1498e44cc4d880607', 'createdAt': 1390241473, 'source': {'name': 'Foursquare for iOS', 'url': 'https://foursquare.com/download/#/iphone'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/1511_8ztIXxHJN52y2tBFS0rN3_WkhVnXzOZ0v_qKM28m54Y.jpg', 'width': 720, 'height': 960, 'visibility': 'public'}]}]}, 'venuePage': {'id': '81824008'}, 'reasons': {'count': 1, 'items': [{'summary': 'Lots of people like this place', 'type': 'general', 'reasonName': 'rawLikesReason'}]}, 'page': {'user': {'firstName': 'Cafe Paulette', 'countryCode': 'US', 'type': 'venuePage', 'venue': {'id': '5250553911d262bb0c732ee8'}, 'tips': {'count': 0}, 'lists': {'groups': [{'type': 'created', 'count': 2, 'items': []}]}, 'bio': ''}}, 'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}, 'createdAt': 1380996409, 'tips': {'count': 53, 'groups': [{'type': 'others', 'name': 'All tips', 'count': 53, 'items': [{'id': '52db8129498efea1a009da6e', 'createdAt': 1390117161, 'text': 'this french toast', 'type': 'user', 'canonicalUrl': 'https://foursquare.com/item/52db8129498efea1a009da6e', 'photo': {'id': '52db812a498e9c7aba5dee1d', 'createdAt': 1390117162, 'source': {'name': '4sq for iOS (internal)', 'url': 'http://developer.foursquare.com'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/47321_VDg-Om8pEWz41w7m8orXs9Vc3_p1IVwuRfMjgZ2ayLY.jpg', 'width': 720, 'height': 960, 'vi ...
#                          ID           Name  Likes  Rating  Tips
# 0  5250553911d262bb0c732ee8  Cafe Paulette    216     8.6    53
# ( 9 / 53 ) processed
# {'meta': {'code': 200, 'requestId': '6031b23ac005d56f9466aed3'}, 'response': {'venue': {'id': '422b9980f964a520d21f1fe3', 'name': 'Maison May', 'contact': {'phone': '7187892778', 'formattedPhone': '(718) 789-2778', 'facebook': '302945113056353', 'facebookUsername': 'maisonmayny', 'facebookName': 'Maison-May'}, 'location': {'address': '246 Dekalb Ave', 'crossStreet': 'at Vanderbilt Avenue', 'lat': 40.68946565224471, 'lng': -73.96929148484402, 'labeledLatLngs': [{'label': 'display', 'lat': 40.68946565224471, 'lng': -73.96929148484402}, {'label': 'entrance', 'lat': 40.689373, 'lng': -73.96934}], 'postalCode': '11205', 'cc': 'US', 'city': 'Brooklyn', 'state': 'NY', 'country': 'United States', 'formattedAddress': ['246 Dekalb Ave (at Vanderbilt Avenue)', 'Brooklyn, NY 11205', 'United States']}, 'canonicalUrl': 'https://foursquare.com/v/maison-may/422b9980f964a520d21f1fe3', 'categories': [{'id': '4bf58dd8d48988d10c941735', 'name': 'French Restaurant', 'pluralName': 'French Restaurants', 'shortName': 'French', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/french_', 'suffix': '.png'}, 'primary': True}, {'id': '4bf58dd8d48988d16d941735', 'name': 'Café', 'pluralName': 'Cafés', 'shortName': 'Café', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_', 'suffix': '.png'}}], 'verified': True, 'stats': {'tipCount': 51}, 'url': 'http://www.maison-may.com', 'price': {'tier': 3, 'message': 'Expensive', 'currency': '$'}, 'hasMenu': True, 'likes': {'count': 110, 'groups': [{'type': 'others', 'count': 110, 'items': []}], 'summary': '110 Likes'}, 'dislike': False, 'ok': False, 'rating': 8.4, 'ratingColor': '73CF42', 'ratingSignals': 175, 'menu': {'type': 'Menu', 'label': 'Menu', 'anchor': 'View Menu', 'url': 'http://www.icirestaurant.com/menu/', 'mobileUrl': 'http://www.icirestaurant.com/menu/', 'externalUrl': 'http://www.icirestaurant.com/menu/'}, 'allowMenuUrlEdit': True, 'beenHere': {'count': 0, 'unconfirmedCount': 0, 'marked': False, 'lastCheckinExpiredAt': 0}, 'specials': {'count': 0, 'items': []}, 'photos': {'count': 116, 'groups': [{'type': 'venue', 'name': 'Venue photos', 'count': 116, 'items': [{'id': '4fdc9befe4b090d3f5b27fcb', 'createdAt': 1339857903, 'source': {'name': 'Foursquare for iOS', 'url': 'https://foursquare.com/download/#/iphone'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/Up_bxVavBmNdq6D7w4j4f-r7cTC4dsZa3PZt0UgMR7w.jpg', 'width': 720, 'height': 537, 'visibility': 'public'}]}]}, 'venuePage': {'id': '46200085'}, 'reasons': {'count': 1, 'items': [{'summary': 'Lots of people like this place', 'type': 'general', 'reasonName': 'rawLikesReason'}]}, 'storeId': '', 'page': {'user': {'firstName': 'Maison May', 'countryCode': 'US', 'type': 'venuePage', 'venue': {'id': '422b9980f964a520d21f1fe3'}, 'tips': {'count': 0}, 'lists': {'groups': [{'type': 'created', 'count': 2, 'items': []}]}, 'bio': ''}}, 'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}, 'createdAt': 1110153600, 'tips': {'count': 51, 'groups': [{'type': 'others', 'name': 'All tips', 'count': 51, 'items': [{'id': '50c93b82e4b06467fe70a14b', 'createdAt': 1355365250, 'text': "I wanted to slap myself In the face for not coming here only now in the 2ish years I've lived nearby.", 'type': 'user', 'canonicalUrl': 'https://foursquare.com/item/50c93b82e4b06467fe70a14b', 'lang': 'en', 'likes': {'count': 7, 'groups': [{'type': 'others', 'count': 7, 'items': [{'firstName': 'Nate', 'lastName': 'S', 'address': '', 'city': '', 'state': '', 'countryCode': 'US'}, {'firstName': 'Greg', 'lastName': 'W', 'countryCode': 'US'}, {'firstName': 'Erica', 'countryCode': 'US'}, {'firstName': 'WEI', 'lastName': 'W', 'countryCode': 'US'}]}], 'summary': '7 likes'}, 'logView': True, 'agreeCount': 7, 'disagreeCount': 0, 'todo': {'count': 1}, 'user': {'firstName': 'Mark', 'lastName': 'E', 'countryCode': 'US'}}]}]}, 'shortUrl': 'http://4sq.com/90F9WL', 'timeZone': 'America/New_York', 'listed': {'count': 246, 'groups': [{'type': 'others', 'na ...
#                          ID        Name  Likes  Rating  Tips
# 0  422b9980f964a520d21f1fe3  Maison May    110     8.4    51
# ( 10 / 53 ) processed
# {'meta': {'code': 200, 'requestId': '6031b23a94926610d3727c3e'}, 'response': {'venue': {'id': '5ca3681932b61d0039533330', 'name': 'Pret A Manger', 'contact': {}, 'location': {'address': '2 Metrotech Ctr', 'crossStreet': 'Bridge Street', 'lat': 40.693555, 'lng': -73.985378, 'labeledLatLngs': [{'label': 'display', 'lat': 40.693555, 'lng': -73.985378}], 'postalCode': '11201', 'cc': 'US', 'city': 'Brooklyn', 'state': 'NY', 'country': 'United States', 'formattedAddress': ['2 Metrotech Ctr (Bridge Street)', 'Brooklyn, NY 11201', 'United States']}, 'canonicalUrl': 'https://foursquare.com/v/pret-a-manger/5ca3681932b61d0039533330', 'categories': [{'id': '4bf58dd8d48988d10c941735', 'name': 'French Restaurant', 'pluralName': 'French Restaurants', 'shortName': 'French', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/french_', 'suffix': '.png'}, 'primary': True}], 'verified': True, 'stats': {'tipCount': 3}, 'price': {'tier': 3, 'message': 'Expensive', 'currency': '$'}, 'likes': {'count': 1, 'groups': [{'type': 'others', 'count': 1, 'items': [{'firstName': 'Mei', 'lastName': 'T', 'countryCode': 'US'}]}], 'summary': '1 Like'}, 'dislike': False, 'ok': False, 'rating': 7.2, 'ratingColor': 'C5DE35', 'ratingSignals': 1, 'delivery': {'id': '2132118', 'url': 'https://www.seamless.com/menu/pret-a-manger-2-metrotech-center-brooklyn/2132118?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2132118', 'provider': {'name': 'seamless', 'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/', 'sizes': [40, 50], 'name': '/delivery_provider_seamless_20180129.png'}}}, 'allowMenuUrlEdit': True, 'beenHere': {'count': 0, 'unconfirmedCount': 0, 'marked': False, 'lastCheckinExpiredAt': 0}, 'specials': {'count': 0, 'items': []}, 'photos': {'count': 3, 'groups': [{'type': 'venue', 'name': 'Venue photos', 'count': 3, 'items': [{'id': '5dc052f02750490008930356', 'createdAt': 1572885232, 'source': {'name': 'Foursquare for iOS', 'url': 'https://foursquare.com/download/#/iphone'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/10658105_jAdW41d7gnmVNzyNl9C7pMp1dso7iZ6yVl_rH8RmkD0.jpg', 'width': 1440, 'height': 1920, 'visibility': 'public'}]}]}, 'venuePage': {'id': '1359972359'}, 'reasons': {'count': 0, 'items': []}, 'description': 'Founded in London in 1986, Pret A Manger is a fast casual restaurant serving organic coffee, hot breakfast, sandwiches, salads and wraps made throughout the day using carefully sourced ingredients.', 'page': {'user': {'firstName': 'Pret A Manger', 'countryCode': 'US', 'type': 'venuePage', 'venue': {'id': '5ca3681932b61d0039533330'}, 'tips': {'count': 0}, 'lists': {'groups': [{'type': 'created', 'count': 2, 'items': []}]}, 'bio': ''}}, 'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}, 'createdAt': 1554212889, 'tips': {'count': 3, 'groups': [{'type': 'others', 'name': 'All tips', 'count': 3, 'items': [{'id': '5cc871336fd626002c4e25b5', 'createdAt': 1556640051, 'text': 'The coffee!', 'type': 'user', 'canonicalUrl': 'https://foursquare.com/item/5cc871336fd626002c4e25b5', 'photo': {'id': '5cc87135c824ae003987d013', 'createdAt': 1556640053, 'source': {'name': 'Foursquare for iOS', 'url': 'https://foursquare.com/download/#/iphone'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/10658105_0e5fz_Bw9q4CtGKZ9NIMETXDrp6dAmHfbSxwwG3OYsU.jpg', 'width': 1440, 'height': 1920, 'visibility': 'public'}, 'photourl': 'https://fastly.4sqi.net/img/general/original/10658105_0e5fz_Bw9q4CtGKZ9NIMETXDrp6dAmHfbSxwwG3OYsU.jpg', 'lang': 'en', 'likes': {'count': 0, 'groups': []}, 'logView': True, 'agreeCount': 1, 'disagreeCount': 0, 'todo': {'count': 0}, 'user': {'firstName': 'Mei', 'lastName': 'T', 'countryCode': 'US'}, 'authorInteractionType': 'liked'}]}]}, 'shortUrl': 'https://4sq.com/2UbYi3r', 'timeZone': 'America/New_York', 'listed': {'count': 2, 'groups': [{'type': 'others', 'name': 'Lists from other people', 'count': 2, 'items': [{'id': '5c33602 ...
#                          ID           Name  Likes  Rating  Tips
# 0  5ca3681932b61d0039533330  Pret A Manger      1     7.2     3
# ( 11 / 53 ) processed
# ...
#                          ID     Name  Likes  Rating  Tips
# 0  534c9d7b498e1bdd443a40e1  Racines    120     8.5    37
# ( 47 / 53 ) processed
# {'meta': {'code': 200, 'requestId': '6031b242f3484c1e429f9980'}, 'response': {'venue': {'id': '3fd66200f964a52083e61ee3', 'name': 'The Odeon', 'contact': {'phone': '2122330507', 'formattedPhone': '(212) 233-0507', 'twitter': 'theodeonnyc'}, 'location': {'address': '145 W Broadway', 'crossStreet': 'at Thomas St', 'lat': 40.71701011409906, 'lng': -74.00804244562225, 'labeledLatLngs': [{'label': 'display', 'lat': 40.71701011409906, 'lng': -74.00804244562225}], 'postalCode': '10013', 'cc': 'US', 'city': 'New York', 'state': 'NY', 'country': 'United States', 'formattedAddress': ['145 W Broadway (at Thomas St)', 'New York, NY 10013', 'United States']}, 'canonicalUrl': 'https://foursquare.com/v/the-odeon/3fd66200f964a52083e61ee3', 'categories': [{'id': '4bf58dd8d48988d10c941735', 'name': 'French Restaurant', 'pluralName': 'French Restaurants', 'shortName': 'French', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/french_', 'suffix': '.png'}, 'primary': True}, {'id': '4bf58dd8d48988d116941735', 'name': 'Bar', 'pluralName': 'Bars', 'shortName': 'Bar', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_', 'suffix': '.png'}}], 'verified': True, 'stats': {'tipCount': 210}, 'url': 'http://www.theodeonrestaurant.com', 'price': {'tier': 2, 'message': 'Moderate', 'currency': '$'}, 'hasMenu': True, 'likes': {'count': 722, 'groups': [{'type': 'others', 'count': 722, 'items': []}], 'summary': '722 Likes'}, 'dislike': False, 'ok': False, 'rating': 8.7, 'ratingColor': '73CF42', 'ratingSignals': 1002, 'menu': {'type': 'Menu', 'label': 'Menu', 'anchor': 'View Menu', 'url': 'https://foursquare.com/v/the-odeon/3fd66200f964a52083e61ee3/menu', 'mobileUrl': 'https://foursquare.com/v/3fd66200f964a52083e61ee3/device_menu'}, 'allowMenuUrlEdit': True, 'beenHere': {'count': 0, 'unconfirmedCount': 0, 'marked': False, 'lastCheckinExpiredAt': 0}, 'specials': {'count': 0, 'items': []}, 'photos': {'count': 511, 'groups': [{'type': 'venue', 'name': 'Venue photos', 'count': 511, 'items': [{'id': '516de022498edba44e4f9543', 'createdAt': 1366155298, 'source': {'name': 'Instagram', 'url': 'http://instagram.com'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/28517_wbI3Ofav7DuuqKXpuxtnKEUubC58AFVf-YkHkXKYZhA.jpg', 'width': 612, 'height': 612, 'visibility': 'public'}]}]}, 'venuePage': {'id': '97281190'}, 'reasons': {'count': 1, 'items': [{'summary': 'Lots of people like this place', 'type': 'general', 'reasonName': 'rawLikesReason'}]}, 'description': 'The Odeon is a classic bistro, serving French Bistro fare with American accents.', 'storeId': '', 'page': {'user': {'firstName': 'The Odeon', 'countryCode': 'US', 'type': 'venuePage', 'venue': {'id': '3fd66200f964a52083e61ee3'}, 'tips': {'count': 0}, 'lists': {'groups': [{'type': 'created', 'count': 2, 'items': []}]}, 'bio': ''}}, 'hereNow': {'count': 2, 'summary': '2 people are here', 'groups': [{'type': 'others', 'name': 'Other people here', 'count': 2, 'items': []}]}, 'createdAt': 1071014400, 'tips': {'count': 210, 'groups': [{'type': 'others', 'name': 'All tips', 'count': 210, 'items': [{'id': '4bed9a4070c603bbc57c9bb4', 'createdAt': 1273862720, 'text': "American Psychos down salmon and steak frites, but the real scene's on the sidewalk. -Andy Cohen, Watch What Happens Live!", 'type': 'user', 'canonicalUrl': 'https://foursquare.com/item/4bed9a4070c603bbc57c9bb4', 'lang': 'en', 'likes': {'count': 11, 'groups': [{'type': 'others', 'count': 11, 'items': []}], 'summary': '11 likes'}, 'logView': True, 'agreeCount': 11, 'disagreeCount': 0, 'todo': {'count': 415}, 'user': {'firstName': 'Bravo', 'countryCode': 'US', 'type': 'page'}}]}]}, 'shortUrl': 'http://4sq.com/3RIbvW', 'timeZone': 'America/New_York', 'listed': {'count': 1000, 'groups': [{'type': 'others', 'name': 'Lists from other people', 'count': 1000, 'items': [{'id': '4e31d44c15203b32db8edb7c', 'name': 'Beyond Eats!', 'description': 'Find some fabulous food from our brand evangelists. (Have dessert, because we also  ...
#                          ID       Name  Likes  Rating  Tips
# 0  3fd66200f964a52083e61ee3  The Odeon    722     8.7   210
# ( 48 / 53 ) processed
# {'meta': {'code': 200, 'requestId': '6031b2423e9575501b853170'}, 'response': {'venue': {'id': '5b06b57962845c00242fb6be', 'name': 'Maison Kayser', 'contact': {'phone': '2125278100', 'formattedPhone': '(212) 527-8100'}, 'location': {'address': '339 7th Ave', 'crossStreet': '29th Street', 'lat': 40.7477318859394, 'lng': -73.99287729714396, 'labeledLatLngs': [{'label': 'display', 'lat': 40.7477318859394, 'lng': -73.99287729714396}], 'postalCode': '10001', 'cc': 'US', 'city': 'New York', 'state': 'NY', 'country': 'United States', 'formattedAddress': ['339 7th Ave (29th Street)', 'New York, NY 10001', 'United States']}, 'canonicalUrl': 'https://foursquare.com/v/maison-kayser/5b06b57962845c00242fb6be', 'categories': [{'id': '4bf58dd8d48988d10c941735', 'name': 'French Restaurant', 'pluralName': 'French Restaurants', 'shortName': 'French', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/french_', 'suffix': '.png'}, 'primary': True}, {'id': '4bf58dd8d48988d1e0931735', 'name': 'Coffee Shop', 'pluralName': 'Coffee Shops', 'shortName': 'Coffee Shop', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_', 'suffix': '.png'}}, {'id': '4bf58dd8d48988d16a941735', 'name': 'Bakery', 'pluralName': 'Bakeries', 'shortName': 'Bakery', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_', 'suffix': '.png'}}], 'verified': False, 'stats': {'tipCount': 5}, 'url': 'http://maison-kayser-usa.com/20_339_seventh_avenue/', 'price': {'tier': 3, 'message': 'Expensive', 'currency': '$'}, 'likes': {'count': 34, 'groups': [{'type': 'others', 'count': 34, 'items': []}], 'summary': '34 Likes'}, 'dislike': False, 'ok': False, 'rating': 8.1, 'ratingColor': '73CF42', 'ratingSignals': 44, 'allowMenuUrlEdit': True, 'beenHere': {'count': 0, 'unconfirmedCount': 0, 'marked': False, 'lastCheckinExpiredAt': 0}, 'specials': {'count': 0, 'items': []}, 'photos': {'count': 103, 'groups': [{'type': 'venue', 'name': 'Venue photos', 'count': 103, 'items': [{'id': '5e52d0d2ba03bd0008f43212', 'createdAt': 1582485714, 'source': {'name': 'Swarm for iOS', 'url': 'https://www.swarmapp.com'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/45304564_f0QywZXzEbPTAM4CH64MG8GodXhXWK2KdUTubel_it8.jpg', 'width': 1920, 'height': 1440, 'visibility': 'public'}]}]}, 'reasons': {'count': 1, 'items': [{'summary': 'Lots of people like this place', 'type': 'general', 'reasonName': 'rawLikesReason'}]}, 'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}, 'createdAt': 1527166329, 'tips': {'count': 5, 'groups': [{'type': 'others', 'name': 'All tips', 'count': 5, 'items': [{'id': '5b1a9fe13e6741002c05bd3d', 'createdAt': 1528471521, 'text': 'Quick service. Nice late with strong coffee.', 'type': 'user', 'canonicalUrl': 'https://foursquare.com/item/5b1a9fe13e6741002c05bd3d', 'lang': 'en', 'likes': {'count': 1, 'groups': [{'type': 'others', 'count': 1, 'items': [{'firstName': 'Jens', 'lastName': 'L', 'countryCode': 'SE'}]}], 'summary': '1 like'}, 'logView': True, 'agreeCount': 3, 'disagreeCount': 0, 'todo': {'count': 0}, 'user': {'firstName': 'Denis', 'lastName': 'C', 'countryCode': 'BR'}, 'authorInteractionType': 'liked'}]}]}, 'shortUrl': 'https://4sq.com/2x8SCvX', 'timeZone': 'America/New_York', 'listed': {'count': 10, 'groups': [{'type': 'others', 'name': 'Lists from other people', 'count': 10, 'items': [{'id': '52a110c2498e8e044b199c4b', 'name': 'NYC', 'description': '', 'type': 'others', 'user': {'firstName': 'Denis', 'lastName': 'C', 'countryCode': 'BR'}, 'editable': False, 'public': True, 'collaborative': False, 'url': '/user/61022962/list/nyc', 'canonicalUrl': 'https://foursquare.com/user/61022962/list/nyc', 'createdAt': 1386287298, 'updatedAt': 1528644425, 'followers': {'count': 1}, 'listItems': {'count': 32, 'items': [{'id': 'v5b06b57962845c00242fb6be', 'createdAt': 1528465514}]}}, {'id': '57d4a005cd10c04eb2e35ac4', 'name': 'Try Soon', 'description': '', 'type': 'others', 'user': {'firstName': 'David', 'lastName': 'O ...
#                          ID           Name  Likes  Rating  Tips
# 0  5b06b57962845c00242fb6be  Maison Kayser     34     8.1     5
# ( 49 / 53 ) processed
# {'meta': {'code': 200, 'requestId': '6031b2433e9575501b8531c0'}, 'response': {'venue': {'id': '4b70825df964a520e01e2de3', 'name': 'Bistro Vendome', 'contact': {'phone': '2129359100', 'formattedPhone': '(212) 935-9100'}, 'location': {'address': '405 E 58th St', 'crossStreet': '1st Ave', 'lat': 40.75911454459662, 'lng': -73.96169818030543, 'labeledLatLngs': [{'label': 'display', 'lat': 40.75911454459662, 'lng': -73.96169818030543}], 'postalCode': '10022', 'cc': 'US', 'city': 'New York', 'state': 'NY', 'country': 'United States', 'formattedAddress': ['405 E 58th St (1st Ave)', 'New York, NY 10022', 'United States']}, 'canonicalUrl': 'https://foursquare.com/v/bistro-vendome/4b70825df964a520e01e2de3', 'categories': [{'id': '4bf58dd8d48988d10c941735', 'name': 'French Restaurant', 'pluralName': 'French Restaurants', 'shortName': 'French', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/french_', 'suffix': '.png'}, 'primary': True}], 'verified': False, 'stats': {'tipCount': 10}, 'url': 'http://bistrovendomenyc.com', 'price': {'tier': 4, 'message': 'Very Expensive', 'currency': '$'}, 'hasMenu': True, 'likes': {'count': 30, 'groups': [{'type': 'others', 'count': 30, 'items': []}], 'summary': '30 Likes'}, 'dislike': False, 'ok': False, 'rating': 8.1, 'ratingColor': '73CF42', 'ratingSignals': 49, 'menu': {'type': 'Menu', 'label': 'Menu', 'anchor': 'View Menu', 'url': 'https://foursquare.com/v/bistro-vendome/4b70825df964a520e01e2de3/menu', 'mobileUrl': 'https://foursquare.com/v/4b70825df964a520e01e2de3/device_menu'}, 'allowMenuUrlEdit': True, 'beenHere': {'count': 0, 'unconfirmedCount': 0, 'marked': False, 'lastCheckinExpiredAt': 0}, 'specials': {'count': 0, 'items': []}, 'photos': {'count': 25, 'groups': [{'type': 'venue', 'name': 'Venue photos', 'count': 25, 'items': [{'id': '53542a20498ef0a3155d5314', 'createdAt': 1398024736, 'source': {'name': 'Foursquare for iOS', 'url': 'https://foursquare.com/download/#/iphone'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/44563176_9Rfbrq1uP0s0FXzZhFgzf8_tA2OxUT0xIBc9xNUYzP0.jpg', 'width': 720, 'height': 720, 'visibility': 'public'}]}]}, 'reasons': {'count': 0, 'items': []}, 'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}, 'createdAt': 1265664605, 'tips': {'count': 10, 'groups': [{'type': 'others', 'name': 'All tips', 'count': 10, 'items': [{'id': '52acac5c11d2f11db7772dca', 'createdAt': 1387048028, 'text': 'Great onion soup & mussels.', 'type': 'user', 'canonicalUrl': 'https://foursquare.com/item/52acac5c11d2f11db7772dca', 'lang': 'en', 'likes': {'count': 2, 'groups': [{'type': 'others', 'count': 2, 'items': [{'firstName': 'Romario', 'lastName': 'S', 'countryCode': 'BR'}, {'firstName': 'Jennifer', 'lastName': 'M', 'countryCode': 'US'}]}], 'summary': '2 likes'}, 'logView': True, 'agreeCount': 2, 'disagreeCount': 0, 'todo': {'count': 0}, 'user': {'firstName': 'Carla', 'lastName': 'M', 'countryCode': 'US'}}]}]}, 'shortUrl': 'http://4sq.com/a7SO48', 'timeZone': 'America/New_York', 'listed': {'count': 30, 'groups': [{'type': 'others', 'name': 'Lists from other people', 'count': 30, 'items': [{'id': '4e5a56e1cc3f85b29cb24684', 'name': 'Must-visit Food in New York', 'description': '', 'type': 'others', 'user': {'firstName': 'Katie', 'lastName': 'P', 'countryCode': 'US'}, 'editable': False, 'public': True, 'collaborative': False, 'url': '/scarletzin/list/mustvisit-food-in-new-york', 'canonicalUrl': 'https://foursquare.com/scarletzin/list/mustvisit-food-in-new-york', 'createdAt': 1314543329, 'updatedAt': 1356653436, 'followers': {'count': 1}, 'listItems': {'count': 14, 'items': [{'id': 'v4b70825df964a520e01e2de3', 'createdAt': 1314543329}]}}, {'id': '50017869e4b07b957607cab5', 'name': 'French Restaurant Week', 'description': '', 'type': 'others', 'user': {'firstName': 'Hongchang', 'lastName': 'W', 'countryCode': 'US'}, 'editable': False, 'public': True, 'collaborative': False, 'url': '/hongchangwu/list/french-restaurant-week', 'canonicalUrl': 'https://foursq ...
#                          ID            Name  Likes  Rating  Tips
# 0  4b70825df964a520e01e2de3  Bistro Vendome     30     8.1    10
# ( 50 / 53 ) processed
# {'meta': {'code': 429, 'errorType': 'quota_exceeded', 'errorDetail': 'Quota exceeded', 'requestId': '6031b243051c9e661693beaf'}, 'response': {}}
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-22-ba6d584cd6d8> in <module>
#      11     Borough,Neighborhood,ID,Name=row
#      12     try:
# ---> 13         venue_details=get_venue_details(ID)
#      14         print(venue_details)
#      15         id,name,likes,rating,tips=venue_details.values.tolist()[0]
#
# <ipython-input-5-59d9ba516a6e> in get_venue_details(venue_id)
#      78     results = requests.get(url).json()
#      79     print(results)
# ---> 80     venue_data=results['response']['venue']
#      81     venue_details=[]
#      82     try:
#
# KeyError: 'venue'

# %%
{
    "tags":[
        "remove-input",
    ]
}
stats_french_rest.to_csv('stats_french_rest_csv.csv', index=False)

# %%
{
    "tags":[
        "hide-input",
    ]
}

stats_french_rest = pd.read_csv('stats_french_rest_csv.csv')
stats_french_rest.head()
# Out:
#     Borough     Neighborhood                        ID                   Name  \
# 0     Bronx      City Island  4d7aa83ee540f04d66ba16dc              Bistro SK
# 1  Brooklyn       Greenpoint  5bf358689fca56002c251a87                Citroën
# 2  Brooklyn       Greenpoint  4bcf1883c564ef3ba33beff0               Le Gamin
# 3  Brooklyn  Windsor Terrace  4aee2d5cf964a520b7d221e3  Le P'tit Paris Bistro
# 4  Brooklyn         Bushwick  55e47d26498e44d12c7c004e              Le Garage
#
#    Likes  Rating  Tips
# 0     12     7.5     7
# 1     23     8.6     3
# 2    159     7.6    73
# 3     55     7.5    32
# 4     99     7.9    25

# %% [markdown]
# ### A deep analysis of rating shows the distribution of rating of french restaurants per Neighborhood. The tables above and below show that the best rating for restaurants are those located in Manhattan. Perhaps restaurants in Queens and in other Boroughs suffer from mismanagement.

# %%
{
    "tags":[
        "hide-input",
    ]
}

stats_french_rest.tail()
# Out:
#       Borough   Neighborhood                        ID            Name  Likes  \
# 45  Manhattan           Noho  556b8dc2498eb674c015c301         Wildair    265
# 46  Manhattan   Civic Center  534c9d7b498e1bdd443a40e1         Racines    120
# 47  Manhattan   Civic Center  3fd66200f964a52083e61ee3       The Odeon    722
# 48  Manhattan  Midtown South  5b06b57962845c00242fb6be   Maison Kayser     34
# 49  Manhattan   Sutton Place  4b70825df964a520e01e2de3  Bistro Vendome     30
#
#     Rating  Tips
# 45     8.7    74
# 46     8.5    37
# 47     8.7   210
# 48     8.1     5
# 49     8.1    10

# %%
{
    "tags":[
        "hide-input",
    ]
}

stats = stats_french_rest.groupby('Borough',as_index=False).mean()[['Borough','Rating']]
stats.columns=['Borough','Average Rating']
stats.sort_values(['Average Rating'],ascending=False)
# Out:
#      Borough  Average Rating
# 2  Manhattan        8.476471
# 1   Brooklyn        8.071429
# 0      Bronx        7.500000
# 3     Queens        0.000000

# %% [markdown]
# ### The average rating for each Borough (table above) is very meaningful. Restaurants in Manhattan have the best rating. They are followed by those in Brooklyn, then by those in Bronx. Restaurants in Queens got a shameful rating. This finding should bring the management of said restaurants to a complete review of the processes in order to gain values in the sight of customers.

# %%
{
    "tags":[
        "hide-input",
    ]
}

address = 'Queens,NYC'

geolocator = Nominatim(user_agent='foursquare_agent')
location = geolocator.geocode(address)
latitude_x = location.latitude
longitude_y = location.longitude
print('The Geograpical Co-ordinate of Queens,NYC are {}, {}.'.format(latitude_x, longitude_y))
# Out:
# The Geograpical Co-ordinate of Queens,NYC are 40.7498243, -73.7976337.

# %% [markdown]
# ## Map of Queens

# %%
{
    "tags":[
        "hide-input",
    ]
}

map_Queens = folium.Map(location=[latitude_x, longitude_y], zoom_start=10)
for lat, lng, nei in zip(newyork_data['Latitude'], newyork_data['Longitude'], newyork_data['Neighborhood']):
    
    label = '{}'.format(nei)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_Queens)  
    
map_Queens
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_6f772bbafc07436082d03b59f1b2a54d%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_6f772bbafc07436082d03b59f1b2a54d%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_6f772bbafc07436082d03b59f1b2a54d%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_6f772bbafc07436082d03b59f1b2a54d%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B40.7498243%2C%20-73.7976337%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20% ...
